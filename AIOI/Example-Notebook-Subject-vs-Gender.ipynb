# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import tensorflow.compat.v1 as tf
import numpy as np
import scipy
import pandas as pd

from generatorMT import BatchGeneratorFilterNew
import matplotlib.pyplot as plt

from IPython.display import clear_output
import matplotlib.pyplot as plt
from utils import *
from module import *
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %% [markdown]
# # "Global" config variables

# %%
tf.test.gpu_device_name(), tf.config.list_physical_devices('GPU')
# Out:
# ('/device:GPU:0',
#  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')])

# %%
model_name='SubjectVsGender'
pretrain_checkpoint_dir='basecheckpoint' #dir with checkpoints for the pretrain nw
train_checkpoint_dir='checkpoint' #dir with checkpoints for the trained nw
use_batchnorm_classifiers=True
use_batchnorm_filter =False
image_size=128
n_channels=1
load_pretrained_classifiers=True
pretrain_classifiers=False
load_pretrained_filter=True
pretrain_filter=False

# %% [markdown]
# # import data pickles

# %%
df =pd.read_pickle('Facescrub_pandas_reduced.pkl')

# %%
df.head(2)
# Out:
#     index                                           filepath  \
# 165   165  /data/Facescrub/Sarah_Michelle_Gellar/Sarah_Mi...
# 166   166  /data/Facescrub/Sarah_Michelle_Gellar/Sarah_Mi...
#
#                subject_str gender_str subject_number gender_number
# 165  Sarah_Michelle_Gellar     female              0             1
# 166  Sarah_Michelle_Gellar     female              0             1

# %%
subjects = {}
for idx, _ in df.iterrows():
    subjects[_['subject_str']] = _['subject_number']
print('Number of subjects: {}'.format(len(subjects)))
# Out:
# Number of subjects: 200

# %%
male = {}
female = {}
data = {}
for type_, dict_ in zip(['actors', 'actresses'], [male, female]):
    with open('../facescrub/facescrub_{}.txt'.format(type_), 'r') as file:
        line = file.readline()
        line = file.readline()
        while line:
            dict_[line.split('\t')[0].replace(' ', '_')]=True
            line = file.readline()
print("Number of males: {}\nNumber of females: {}".format(len(male), len(female)))
# Out:
# Number of males: 265
# Number of females: 265

# %%
data_path = '/data/FaceScrub/'
data = []
for person in os.listdir(data_path):
    facepath = os.path.join(data_path, person, 'face')
    gender = 'female'
    gender_number = 1
    person_str = person.replace(' ', '_')
    if person_str in subjects:
        if person_str in male:
            gender = 'male'
            gender_number = 0
        for image in os.listdir(facepath):
            data.append([os.path.join(facepath, image), person_str, gender, subjects[person_str], gender_number])

df_new = pd.DataFrame(data, columns=['filepath', 'subject_str', 'gender_str', 'subject_number', 'gender_number'])
df_new.head(2)
# Out:
#                                             filepath      subject_str  \
# 0  /data/FaceScrub/Joe_Manganiello/face/ccc38a04b...  Joe_Manganiello
# 1  /data/FaceScrub/Joe_Manganiello/face/72b2d4b6c...  Joe_Manganiello
#
#   gender_str  subject_number  gender_number
# 0       male             184              0
# 1       male             184              0

# %%
df_new.gender_str.value_counts().plot(kind='bar', color='b')
plt.show()

# %%
df['systempath'] = df.filepath.apply(
    lambda x: '/'.join(['/WorkSpace/FaceScrub/images'] + x.split('/')[3:]))
df['isvalidpath'] = df.systempath.apply(os.path.isfile)
df.head()
# Out:
#     index                                           filepath  \
# 165   165  /data/Facescrub/Sarah_Michelle_Gellar/Sarah_Mi...
# 166   166  /data/Facescrub/Sarah_Michelle_Gellar/Sarah_Mi...
# 167   167  /data/Facescrub/Sarah_Michelle_Gellar/Sarah_Mi...
# 168   168  /data/Facescrub/Sarah_Michelle_Gellar/Sarah_Mi...
# 169   169  /data/Facescrub/Sarah_Michelle_Gellar/Sarah_Mi...
#
#                subject_str gender_str subject_number gender_number  \
# 165  Sarah_Michelle_Gellar     female              0             1
# 166  Sarah_Michelle_Gellar     female              0             1
# 167  Sarah_Michelle_Gellar     female              0             1
# 168  Sarah_Michelle_Gellar     female              0             1
# 169  Sarah_Michelle_Gellar     female              0             1
#
#                                             systempath  isvalidpath
# 165  /WorkSpace/FaceScrub/images/Sarah_Michelle_Gel...        False
# 166  /WorkSpace/FaceScrub/images/Sarah_Michelle_Gel...        False
# 167  /WorkSpace/FaceScrub/images/Sarah_Michelle_Gel...        False
# 168  /WorkSpace/FaceScrub/images/Sarah_Michelle_Gel...        False
# 169  /WorkSpace/FaceScrub/images/Sarah_Michelle_Gel...        False

# %%
df_new.subject_str.value_counts().plot(kind='bar', color='b')
plt.xticks([])
plt.show()

# %%
df = df_new

# %%
len(np.unique(df.subject_number.tolist()))
# Out:
# 200

# %%
from sklearn.utils import shuffle
np.random.seed(42)
df = shuffle(df)
df.reset_index(inplace=True)
df['utility']=df['subject_number']
df['secret']=df['gender_number']

df_train = df[:int(0.8*len(df))]
df_test = df[int(0.8*len(df)):int(0.9*len(df))]
df_val = df[int(0.9*len(df)):]

print('num train ; num test ; num val')
print(len(df_train),len(df_test),len(df_val))

img_size=(image_size, image_size, n_channels)
secret_list=['secret']
ns=2
utility_list=['utility']
nu=200
batch_size=64

#TODO! remove keras dependency with load_image wrapper
data_generator = BatchGeneratorFilterNew(df_train, training=True, batch_size=batch_size,
    secret_list=secret_list, utility_list=utility_list,
    output_list=['u','s'], input_list=["utility","secret"], img_size=img_size,
    shuffling=True, output_type='categorical', n_secrets=ns,n_utility=nu,)

data_generator_val = BatchGeneratorFilterNew(df_val, training=True, batch_size=batch_size,
    secret_list=secret_list, utility_list=utility_list,
    output_list=['u','s'], input_list=["utility","secret"], img_size=img_size,
    shuffling=True, output_type='categorical', n_secrets=ns,n_utility=nu,)

data_generator_test = BatchGeneratorFilterNew(df_test, training=True, batch_size=batch_size,
    secret_list=secret_list, utility_list=utility_list,
    output_list=['u','s'], input_list=["utility","secret"], img_size=img_size,
    shuffling=True, output_type='categorical', n_secrets=ns,n_utility=nu,)


# Get empirical Marginals and joint u,s distributions from labels
Pus, Pu,Ps = get_data_marginals(df_train,nu,ns)
Pus_test,Pu_test,Ps_test = get_data_marginals(df_test, nu,ns)
Pus_val,Pu_val,Ps_val = get_data_marginals(df_val, nu,ns)

print(' Prior S : ',Ps)
# Out:
# num train ; num test ; num val
# 18212 2276 2277
#  Prior S :  [0.57906875 0.42093125]

# %% [markdown]
# # start of code
# #### Placeholders + outputs + vars

# %%
tf.disable_eager_execution()

# %%
tf.reset_default_graph()

#####
#define all the placeholders for input and output variables
#####
input_image = tf.placeholder(tf.float32,  shape = (None, image_size, image_size, n_channels), name = 'input_image')
utility_gt_ph =  tf.placeholder(tf.float32,  shape = (None, nu), name = 'utility_gt_ph')
secret_gt_ph =  tf.placeholder(tf.float32,  shape = (None, ns), name = 'secret_gt_ph')
secret_prior_ph =  tf.placeholder(tf.float32,  shape = (None, ns), name = 'secret_prior_ph')

#####
# loss-related placeholders
#####
budget_ph =  tf.placeholder(tf.float32,  shape = (), name = 'budget')
lambda_ph =  tf.placeholder(tf.float32,  shape = (), name = 'lambda')
lr_u_ph = tf.placeholder(tf.float32,  shape = (), name = 'lr_u_ph')
lr_u_raw_ph = tf.placeholder(tf.float32,  shape = (), name = 'lr_u_raw_ph')
lr_s_ph = tf.placeholder(tf.float32,  shape = (), name = 'lr_s_ph')
lr_f_ph = tf.placeholder(tf.float32,  shape = (), name = 'lr_f_ph')
lr_c_ph = tf.placeholder(tf.float32,  shape = (), name = 'lr_c_ph')

#####
# Define outputs (separate by batchnorm behaviour)
#####
filter_outputs = filter_model(input_image, is_training=True, use_bn=use_batchnorm_filter)
secret_output_tr = secret_model(input_image, is_training=True,ns=ns, use_bn=use_batchnorm_classifiers)
utility_output_tr = utility_model(input_image, is_training=True,nu=nu, use_bn=use_batchnorm_classifiers)

update_ops_util = tf.get_collection(tf.GraphKeys.UPDATE_OPS, "utility/")
update_ops_util_raw = tf.get_collection(tf.GraphKeys.UPDATE_OPS, "utility_raw/")
update_ops_secret = tf.get_collection(tf.GraphKeys.UPDATE_OPS, "secret/")
update_ops_filter = tf.get_collection(tf.GraphKeys.UPDATE_OPS, "filter/")

utility_raw_output_tr  = utility_raw_model(input_image, is_training=True,nu=nu, use_bn=use_batchnorm_classifiers)
secret_output = secret_model(input_image, is_training=False, reuse=True,ns=ns, use_bn=use_batchnorm_classifiers)
utility_output = utility_model(input_image, is_training=False, reuse=True,nu=nu, use_bn=use_batchnorm_classifiers)
utility_raw_output  = utility_raw_model(input_image, is_training=False, reuse=True,nu=nu, use_bn=use_batchnorm_classifiers)
combined_outputs_tr = combined_model(input_image, is_training=True,nu=nu,ns=ns,
                                     use_bn_c=use_batchnorm_classifiers, use_bn_f=use_batchnorm_filter)

#####
#Get trainable variables
#####
utility_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "utility/")
utility_raw_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "utility_raw/")
secret_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "secret/")
filter_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "filter/")
secret_onlydense_vars=secret_vars[-2:]
utility_vars_denseonly=utility_vars[-2:]
utility_vars_nodense = utility_vars[:-2]

#####
#Create saver objects
#####
utility_saver = tf.train.Saver(utility_vars,max_to_keep=None)
utility_nodense_saver = tf.train.Saver(utility_vars_nodense,max_to_keep=None)
utility_raw_saver = tf.train.Saver(utility_raw_vars,max_to_keep=None)
secret_saver = tf.train.Saver(secret_vars,max_to_keep=None)
filter_saver = tf.train.Saver(filter_vars,max_to_keep=None)

#####
# Create mirror operation from utility_filter to utility_raw, utility_raw only mirrors pretraining on natural images
#####
mirror_ops=[] #Mirror operation to copy weights from utility_filter to utility_raw, only used for initialization after pretraining
for i in np.arange(len(utility_vars)):
    mirror_ops+=[tf.assign(utility_raw_vars[i],utility_vars[i])]

print('num param filter : ',count_parameters(filter_vars))
print('num param utility : ',count_parameters(utility_vars))
print('num param secret : ',count_parameters(secret_vars))
# Out:
# WARNING:tensorflow:From /WorkSpace/AIOI/UnetNetworks3.py:45: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1635: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /WorkSpace/AIOI/ops.py:24: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /WorkSpace/AIOI/UnetNetworks3.py:57: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From /WorkSpace/AIOI/ops.py:16: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
# WARNING:tensorflow:From /WorkSpace/AIOI/XceptionNetworksBig.py:92: separable_conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.SeparableConv2D` instead.
# WARNING:tensorflow:From /WorkSpace/AIOI/XceptionNetworksBig.py:194: average_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.AveragePooling2D instead.
# WARNING:tensorflow:From /WorkSpace/AIOI/XceptionNetworksBig.py:205: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# num param filter :  2260193
# num param utility :  3501312
# num param secret :  3356970

# %% [markdown]
# # Set up loss functions and optimizers

# %%
# dKL losses for utility and secret networks, meant to train against ground truth
utility_loss = KL_loss(utility_gt_ph, utility_output_tr)
utility_raw_loss= KL_loss(utility_gt_ph, utility_raw_output_tr)
secret_loss = KL_loss(secret_gt_ph, secret_output_tr)

# Accuracy
utility_acc = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(utility_output_tr,1),tf.argmax(utility_gt_ph,1)), tf.float32))
utility_raw_acc =  tf.reduce_mean(tf.cast(tf.equal(tf.argmax(utility_raw_output_tr,1),tf.argmax(utility_gt_ph,1)), tf.float32))
secret_acc = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(secret_output_tr,1),tf.argmax(secret_gt_ph,1)), tf.float32))

# MSE loss for filter network, meant to train filter to copy image
filter_loss = tf.losses.mean_squared_error(input_image,filter_outputs)

# Combined loss desglosada en terminos de utlity y secret loss, 
(combined_loss,
 utility_combined_loss,
 secret_combined_loss) = combined_loss_fn(utility_gt_ph,secret_prior_ph, combined_outputs_tr, budget_ph, lambda_ph)

# %%
# Solvers for all losses
with tf.control_dependencies(update_ops_util): #  needed to make sure batch_norm moving averages get updated!
    utility_optimizer = tf.train.AdamOptimizer(learning_rate=lr_u_ph)
    utility_denseonly_solver = utility_optimizer.minimize(utility_loss, var_list=utility_vars_denseonly)
    utility_solver = utility_optimizer.minimize(utility_loss, var_list=utility_vars)

with tf.control_dependencies(update_ops_util_raw): #  needed to make sure batch_norm moving averages get updated! 
    utility_raw_optimizer = tf.train.AdamOptimizer(learning_rate=lr_u_raw_ph)
    utility_raw_solver = utility_raw_optimizer.minimize(utility_raw_loss, var_list=utility_raw_vars)
    
with tf.control_dependencies(update_ops_secret): #  needed to make sure batch_norm moving averages get updated!
    secret_optimizer = tf.train.AdamOptimizer(learning_rate=lr_s_ph)
    secret_solver = secret_optimizer.minimize(secret_loss, var_list=secret_vars)
    secret_onlydense_optimizer = tf.train.AdamOptimizer(learning_rate=lr_s_ph)
    secret_onlydense_solver = secret_onlydense_optimizer.minimize(secret_loss, var_list=secret_onlydense_vars)

with tf.control_dependencies(update_ops_filter): #  needed to make sure batch_norm moving averages get updated!
    filter_optimizer = tf.train.AdamOptimizer(learning_rate=lr_f_ph)
    combined_optimizer = tf.train.AdamOptimizer(learning_rate=lr_c_ph)
    filter_solver = filter_optimizer.minimize(filter_loss, var_list=filter_vars)
    combined_solver = combined_optimizer.minimize(combined_loss, var_list=filter_vars)

# %% [markdown]
# # Summaries

# %%
scalar_summaries={}
# Loss and accuracy summaries for utility and secret
scalar_summaries['utility_raw_acc_ph'] = tf.placeholder(
    tf.float32,  shape = (), name = 'utility_raw_acc_ph')
scalar_summaries['utility_raw_acc'] = tf.summary.scalar(
    "utility_raw_accuracy", scalar_summaries['utility_raw_acc_ph'])
scalar_summaries['utility_acc_ph'] = tf.placeholder(
    tf.float32,  shape = (), name = 'utility_acc_ph')
scalar_summaries['utility_acc'] = tf.summary.scalar(
    "utility_accuracy", scalar_summaries['utility_acc_ph'])
scalar_summaries['utility_raw_loss_ph'] = tf.placeholder(
    tf.float32,  shape = (), name = 'utility_raw_loss_ph')
scalar_summaries['utility_raw_loss'] = tf.summary.scalar(
    "utility_raw_loss", scalar_summaries['utility_raw_loss_ph'])
scalar_summaries['utility_loss_ph'] = tf.placeholder(
    tf.float32,  shape = (), name = 'utility_loss_ph')
scalar_summaries['utility_loss'] = tf.summary.scalar(
    "utility_loss", scalar_summaries['utility_loss_ph'])
scalar_summaries['secret_acc_ph'] = tf.placeholder(
    tf.float32,  shape = (), name = 'secret_acc_ph')
scalar_summaries['secret_acc'] = tf.summary.scalar(
    "secret_accuracy", scalar_summaries['secret_acc_ph'])
scalar_summaries['secret_loss_ph'] = tf.placeholder(
    tf.float32,  shape = (), name = 'secret_loss_ph')
scalar_summaries['secret_loss'] = tf.summary.scalar(
    "secret_loss", scalar_summaries['secret_loss_ph'])
# loss summaries for filter
scalar_summaries['filter_mse_loss_ph'] = tf.placeholder(
    tf.float32,  shape = (), name = 'filter_mse_loss_ph')
scalar_summaries['filter_mse_loss'] = tf.summary.scalar(
    "mse_reconstruction_loss", scalar_summaries['filter_mse_loss_ph'])

scalar_summaries['filter_CIB_loss_ph'] = tf.placeholder(
    tf.float32,  shape = (), name = 'filter_CIB_loss_ph')
scalar_summaries['filter_CIB_loss'] = tf.summary.scalar(
    "CIB_loss", scalar_summaries['filter_CIB_loss_ph'])

scalar_summaries['filter_censored_info_loss_ph'] = tf.placeholder(
    tf.float32,  shape = (), name = 'filter_censored_info_loss_ph')
scalar_summaries['filter_censored_info_loss'] = tf.summary.scalar(
    "Censored_information_loss", scalar_summaries['filter_censored_info_loss_ph'])

scalar_summaries['filter_information_penalty_loss_ph'] = tf.placeholder(
    tf.float32,  shape = (), name = 'filter_information_penalty_loss_ph')
scalar_summaries['filter_information_penalty_loss'] = tf.summary.scalar(
    "Information_penalty_loss", scalar_summaries['filter_information_penalty_loss_ph'])

scalar_summaries['merged_training_losses']= tf.summary.merge(
    [scalar_summaries['utility_acc'],scalar_summaries['utility_loss'],
     scalar_summaries['utility_raw_acc'],scalar_summaries['utility_raw_loss'],
     scalar_summaries['secret_acc'],scalar_summaries['secret_loss'],
     scalar_summaries['filter_CIB_loss'],scalar_summaries['filter_censored_info_loss'],
     scalar_summaries['filter_information_penalty_loss']])


image_summaries={}
image_summaries["real_image"] = tf.summary.image("real_image", input_image, max_outputs=20)
image_summaries["filtered_image"] = tf.summary.image("filtered_image", filter_outputs, max_outputs=20)
image_summaries['merged_image_summary']= tf.summary.merge([image_summaries["real_image"], image_summaries["filtered_image"] ])

# %% [markdown]
# # START OF TRAINING

# %% [markdown]
# # Initialize session

# %%
config = tf.ConfigProto(allow_soft_placement=True)
config.gpu_options.allow_growth = True
sess= tf.Session(config=config)
init = tf.global_variables_initializer()
sess.run(init)

# %%
logdir = './logs/{:s}_BN_filter_{:}_BN_classifier_{:}/'.format(model_name, use_batchnorm_filter, use_batchnorm_classifiers)
writer = tf.summary.FileWriter(logdir+"pretrain")
val_writer = tf.summary.FileWriter(logdir+"pretrain")

# %% [markdown]
# # Reload and/or train classifier networks

# %%
if load_pretrained_classifiers:
    named_path = os.path.join(pretrain_checkpoint_dir, model_name)
    classifier_type_path = 'batch_norm' if use_batchnorm_classifiers else 'instance_norm'
    named_class_path = os.path.join(named_path, classifier_type_path)
    pretrain_checkpoint_dir_ur = os.path.join(named_class_path, 'utility_raw')
    pretrain_checkpoint_dir_uf = os.path.join(named_class_path, 'utility_filtered')
    pretrain_checkpoint_dir_s = os.path.join(named_class_path, 'secret')


    ckpt = tf.train.get_checkpoint_state(pretrain_checkpoint_dir_uf)
    if ckpt and ckpt.model_checkpoint_path:
        ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
        utility_saver.restore(sess, os.path.join(pretrain_checkpoint_dir_uf, ckpt_name))
        ckpt = tf.train.get_checkpoint_state(pretrain_checkpoint_dir_uf)
    ckpt = tf.train.get_checkpoint_state(pretrain_checkpoint_dir_ur)
    if ckpt and ckpt.model_checkpoint_path:
        ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
        utility_raw_saver.restore(sess, os.path.join(pretrain_checkpoint_dir_ur, ckpt_name))
    ckpt = tf.train.get_checkpoint_state(pretrain_checkpoint_dir_s)
    if ckpt and ckpt.model_checkpoint_path:
        ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
        secret_saver.restore(sess, os.path.join(pretrain_checkpoint_dir_s, ckpt_name))
# Out:
# INFO:tensorflow:Restoring parameters from basecheckpoint/SubjectVsGender/batch_norm/utility_filtered/utility_filtered-13999
# INFO:tensorflow:Restoring parameters from basecheckpoint/SubjectVsGender/batch_norm/utility_raw/utility_raw-13999
# INFO:tensorflow:Restoring parameters from basecheckpoint/SubjectVsGender/batch_norm/secret/secret-13999

# %%
from tqdm import tqdm

# %%
len(data_generator)
# Out:
# 285

# %%
if pretrain_classifiers:
    
    n_epochs=50
    n_batches = len(data_generator)


    u_loss_array=np.zeros(n_epochs*n_batches)
    u_acc_array=np.zeros(n_epochs*n_batches)
    s_loss_array=np.zeros(n_epochs*n_batches)
    s_acc_array=np.zeros(n_epochs*n_batches)


    it = -1
    for epoch in range(n_epochs):
        print(epoch)
        data_generator.shuffle()
        for idx in tqdm(np.arange(n_batches), leave=False):
            it+=1

            data_batch = data_generator.__getitem__(idx)
            imgs = data_batch[0][0]
            utility_gt = data_batch[1][0]  
            secret_gt = data_batch[1][1]

            (_,_,
             utility_loss_curr, secret_loss_curr,
             pred_u, pred_s)= sess.run(
                [utility_solver, secret_solver,utility_loss,secret_loss,utility_output, secret_output,
                ], 
                feed_dict={input_image: imgs, utility_gt_ph: utility_gt, secret_gt_ph: secret_gt,
                lr_u_ph: 1e-4, lr_s_ph: 1e-4})            
            
            s_loss_array[it]=secret_loss_curr
            s_acc_array[it]=np.mean(np.argmax(pred_s,1)==secret_gt.argmax(1))

            u_loss_array[it]=utility_loss_curr
            u_acc_array[it]=np.mean(np.argmax(pred_u,1)==utility_gt.argmax(1))


            feed_dict={
                scalar_summaries['utility_acc_ph']: u_acc_array[it],
                scalar_summaries['utility_loss_ph']: u_loss_array[it],
                scalar_summaries['secret_acc_ph']: s_acc_array[it],
                scalar_summaries['secret_loss_ph']: s_loss_array[it],
            }

            scalar_sum_1, scalar_sum_2, scalar_sum_3, scalar_sum_4  = sess.run(
                [scalar_summaries['utility_acc'],
                scalar_summaries['utility_loss'],
                scalar_summaries['secret_acc'],
                scalar_summaries['secret_loss'],],
                feed_dict=feed_dict
            )
            writer.add_summary(scalar_sum_1, it)
            writer.add_summary(scalar_sum_2, it)
            writer.add_summary(scalar_sum_3, it)
            writer.add_summary(scalar_sum_4, it)


            if it %1000 ==999:
                named_path = os.path.join(pretrain_checkpoint_dir, model_name)

                classifier_type_path = 'batch_norm' if use_batchnorm_classifiers else 'instance_norm'
                named_class_path = os.path.join(named_path, classifier_type_path)

                pretrain_checkpoint_dir_ur = os.path.join(named_class_path, 'utility_raw')
                pretrain_checkpoint_dir_uf = os.path.join(named_class_path, 'utility_filtered')
                pretrain_checkpoint_dir_s = os.path.join(named_class_path, 'secret')

                if not os.path.exists(pretrain_checkpoint_dir):
                    os.makedirs(pretrain_checkpoint_dir)
                if not os.path.exists(named_path):
                    os.makedirs(named_path)
                if not os.path.exists(named_class_path):
                    os.makedirs(named_class_path)
                if not os.path.exists(pretrain_checkpoint_dir_ur):
                    os.makedirs(pretrain_checkpoint_dir_ur)
                if not os.path.exists(pretrain_checkpoint_dir_uf):
                    os.makedirs(pretrain_checkpoint_dir_uf)
                if not os.path.exists(pretrain_checkpoint_dir_s):
                    os.makedirs(pretrain_checkpoint_dir_s)


                sess.run(mirror_ops)
                utility_saver.save(sess, os.path.join(pretrain_checkpoint_dir_uf,'utility_filtered'), global_step=it)
                secret_saver.save(sess, os.path.join(pretrain_checkpoint_dir_s,'secret'), global_step=it)
                utility_raw_saver.save(sess,os.path.join(pretrain_checkpoint_dir_ur,'utility_raw'), global_step=it)

# %%
input_image
# Out:
# <tf.Tensor 'input_image:0' shape=(None, 128, 128, 1) dtype=float32>

# %%
data_generator_test.filepath
# Out:
# ['/data/FaceScrub/Jennette_McCurdy/face/fba9e40d62c610f13d1fe4b8b12d889c454d10da.jpg',
#  '/data/FaceScrub/Chris_Klein/face/f23f5590d6d5da1c614c241b747c0e8ad450c63e.jpg',
#  '/data/FaceScrub/Marcia_Cross/face/8f80805c598ee232a5bad32b353e8016f02e7c4d.jpg',
#  '/data/FaceScrub/Charlie_Sheen/face/d0fde0295735b7c19873a2e047187802875ff20b.jpg',
#  '/data/FaceScrub/Holly_Marie_Combs/face/e6802f1bec5aacd4449ce7ac103d34e3f976e1df.jpg',
#  '/data/FaceScrub/Charlie_Sheen/face/54fb0bd473d55e1b0e41f5910c06d9042177fa38.jpg',
#  '/data/FaceScrub/Josh_Hartnett/face/9f23e091fed348e87e8bec21d5ae0482eeffa5e6.jpg',
#  '/data/FaceScrub/Tamala_Jones/face/093dc54225a76dbf14816f83a55546d52d0a7b6d.jpg',
#  '/data/FaceScrub/McKayla_Maroney/face/156e54ffd69cbd9d22652a301896d2393b86e3d8.jpg',
#  '/data/FaceScrub/Lorraine_Bracco/face/57f80d1bcf7e7f08fc1536e86fa78b23d8a86fa1.jpg',
#  '/data/FaceScrub/Josh_Brolin/face/f2eca7f2074581bae857306a6f0938cebd596e69.jpg',
#  '/data/FaceScrub/Laurie_Metcalf/face/77eb413ed7921feca6a83fddc9d33ce413c9a0de.jpg',
#  '/data/FaceScrub/Chris_Kattan/face/c728bc4f17b5441a29dfd2d70fbe4eb8ea2d82ac.jpg',
#  '/data/FaceScrub/Adam_Sandler/face/40d0714c27ea6d3437705cb60bc0a13b1bd7fe15.jpg',
#  '/data/FaceScrub/Adrienne_Barbeau/face/8c2b23033702b4e355e49b9daa2d252fa4aac88c.jpg',
#  '/data/FaceScrub/Diahann_Carroll/face/2e4d283ea37eea2cad7d48a56b764376d7786749.jpg',
#  '/data/FaceScrub/Neve_Campbell/face/3c2b309676da81845fcab1c98bd8a539a96c417c.jpg',
#  '/data/FaceScrub/Sherilyn_Fenn/face/bb819366e3d8f41dad4b9591e5158ed992787bed.jpg',
#  '/data/FaceScrub/Holly_Marie_Combs/face/e8cfb2a3dbccbf520db9a8abb8329b74a5c23c66.jpg',
#  '/data/FaceScrub/Matthew_Perry/face/9aa0ed1c66c1ad074360afee3d62d736c8d3ce6f.jpg',
#  '/data/FaceScrub/Danny_Masterson/face/902e1db0dcf5c74f1f87ed0169726a01b0ea4a8d.jpg',
#  '/data/FaceScrub/Jeanne_Cooper/face/30dccd29590c4b73da64336f21a008f314d99117.jpg',
#  '/data/FaceScrub/Benicio_Del_Toro/face/d819445bb0776c6c2b34b84c388e55061aa6e91c.jpg',
#  '/data/FaceScrub/Sally_Field/face/c9240fcf7db4f5adfbf80419eb1f05e18333fd97.jpg',
#  '/data/FaceScrub/Adam_McKay/face/67aa36a80251a85eabbbb94957340d31a6afc49f.jpg',
#  '/data/FaceScrub/Mackenzie_Aladjem/face/1d5fbedbb92e144644b55dbef8b4c830fc24f228.jpg',
#  '/data/FaceScrub/Gates_McFadden/face/fb2aa55e5a8f29445885d56e3605d860edbaf917.jpg',
#  '/data/FaceScrub/Danny_Masterson/face/5610dada9b5fddc2a40dcab633279f5c07dcb863.jpg',
#  '/data/FaceScrub/Ben_Kingsley/face/97afcc998aa09b8adec691d55de7cb6995b94d73.jpg',
#  '/data/FaceScrub/Marilu_Henner/face/123349a0ebf6b0b4234632c8ad7537eecb5383d5.jpg',
#  '/data/FaceScrub/Tatyana_M._Ali/face/e5ba9dfb9f1074d0f671cf1b9df5bfcfbe326699.jpg',
#  '/data/FaceScrub/Richard_E._Grant/face/0819eb6c30ad4c12eae60b1b973b022bb718492b.jpg',
#  '/data/FaceScrub/Jared_Padalecki/face/dcd4c8aa593ca9f371f701e521133d8bb7a8275f.jpg',
#  '/data/FaceScrub/Glenn_Close/face/1524a3f015393f168478729e4eb41e1d9090cd00.jpg',
#  '/data/FaceScrub/David_Schwimmer/face/d1b71a49bdf9371a9747189b2bd3031d9878f12d.jpg',
#  '/data/FaceScrub/Jon_Voight/face/68f6ad04866e9ed66c39f175700241567498e81f.jpg',
#  '/data/FaceScrub/Laurence_Fishburne/face/2f2f334acbfa45aaf901342dbbfa538d12a29520.jpg',
#  '/data/FaceScrub/Lara_Flynn_Boyle/face/b4224f23f03a937c4f7270c65008c01d4914b357.jpg',
#  '/data/FaceScrub/Tina_Fey/face/3f55f79c07b6e37db62f83a1830f549fe394af13.jpg',
#  '/data/FaceScrub/Christian_Slater/face/b576fdc9702334a2a560de3869b6b17242cf474a.jpg',
#  '/data/FaceScrub/Selena_Gomez/face/15e60f877cad4b2432a2de08717d1d5ef548f431.jpg',
#  '/data/FaceScrub/Amaury_Nolasco/face/b49987919ac76cfd0b259283ca4d342f0ff90388.jpg',
#  '/data/FaceScrub/Glenn_Close/face/28cce4be0f02d47864404c3f9f04af576ffc3252.jpg',
#  '/data/FaceScrub/Emily_Deschanel/face/3438baa9ab021815a86706063832df716b22eb51.jpg',
#  '/data/FaceScrub/Sherilyn_Fenn/face/9935f9fb89ca4a1640d03949d212d6d07d35fdef.jpg',
#  '/data/FaceScrub/Omid_Djalili/face/559a9f30eac1b16d7537e2a447cde4e188c84c11.jpg',
#  '/data/FaceScrub/Eliza_Dushku/face/78a4894f41742933640dd8357ba85f7ed46c452a.jpg',
#  '/data/FaceScrub/Dan_Lauria/face/fb398b9a8c80f4585ad975e0cd74f6b8ff5d3131.jpg',
#  '/data/FaceScrub/Jake_Weber/face/14b4eecbf99fea55578ee29de7a880ea87481ef5.jpg',
#  '/data/FaceScrub/Cheryl_Hines/face/9095d497f7cc7ce22bd3d81216ebe07936d8cf55.jpg',
#  '/data/FaceScrub/Sasha_Alexander/face/876ffe1262b781a535bbc2fc2d4993a5e677445a.jpg',
#  '/data/FaceScrub/George_Clooney/face/444c2425175368512205e752deda4037828cf73d.jpg',
#  '/data/FaceScrub/Christian_Slater/face/90e57d40039ce30965d0edf77be6fb720a2fc71d.jpg',
#  '/data/FaceScrub/John_Cusack/face/5842f407e87c584ceb39bc1474b07e62c26cdd5e.jpg',
#  '/data/FaceScrub/McKayla_Maroney/face/3a945d281df72ca1bdf586e3178a3dc2973284f1.jpg',
#  '/data/FaceScrub/Margaret_Cho/face/dbce3dee4063ef20f557efc9ff42ace08be3f7f9.jpg',
#  '/data/FaceScrub/Oliver_Platt/face/fd6298f8995d9993abcdcf48a6d6bbd7c59113cc.jpg',
#  '/data/FaceScrub/Angie_Harmon/face/01f451433cc16e0adc87c532508c65eeec63d79c.jpg',
#  '/data/FaceScrub/James_Brolin/face/6f288f4b6d8d0dba913d7f9c6f2dfa76fc3534f4.jpg',
#  '/data/FaceScrub/Sally_Field/face/7c4e7af33a9a90337e2b03559b3617b4d9f06d95.jpg',
#  '/data/FaceScrub/Lacey_Chabert/face/d496214d10af6d7f6f192855e53b44ad3574ff3f.jpg',
#  '/data/FaceScrub/Nicolas_Cage/face/735f6e722ce975674ac96411a838666573d64562.jpg',
#  '/data/FaceScrub/Josh_Brolin/face/8ec4b9cf6c7791f13d404cfd4c6b08ffa6fc26af.jpg',
#  '/data/FaceScrub/Brendan_Fraser/face/e001e2dd18574845c26c99afde60ee8ad5d7e38d.jpg',
#  '/data/FaceScrub/Jessica_Capshaw/face/e944ad7f2be3c54053785c6e5481e46785c56551.jpg',
#  '/data/FaceScrub/Alyson_Hannigan/face/722f33eab0a643ef91ca321db43b336c5ea238be.jpg',
#  '/data/FaceScrub/Jared_Padalecki/face/3dde24504d2c803ba458846b5586485114c2df87.jpg',
#  '/data/FaceScrub/Jackie_Chan/face/e86f4d16df294b97796e87aa6d546286e85c3e2f.jpg',
#  '/data/FaceScrub/Wendie_Malick/face/ab41a25891e1a861064db03d38433a3a8db5fcc7.jpg',
#  '/data/FaceScrub/Jackie_Chan/face/edcc0ad122e7342ca7434a1fa58a10a783e7b62e.jpg',
#  '/data/FaceScrub/Jonathan_Rhys_Meyers/face/37a5d0b89aef9a522c728dff6709911c6e058575.jpg',
#  '/data/FaceScrub/Jesse_Eisenberg/face/92869d08b194c59dba6f8471de6c2fea164b9fd9.jpg',
#  '/data/FaceScrub/Christian_Slater/face/3221ea1b6aa04252e5f5bc38c58bd965cbbeea35.jpg',
#  '/data/FaceScrub/Matthew_Perry/face/3d09fc27949a6381d900758233148bce84852527.jpg',
#  '/data/FaceScrub/Eric_Dane/face/f8b996ebb97badf308a7ed1c3bc5e8fd4a4f1117.jpg',
#  '/data/FaceScrub/J.K._Simmons/face/2ada08838e125ffaa8d984d9e2e099ab9956098d.jpg',
#  '/data/FaceScrub/Josh_Brolin/face/9396ea4a8c4dab55bb78a84512b4cf95e1f22acc.jpg',
#  '/data/FaceScrub/Lesley-Anne_Down/face/c0d7eee4b182cb57f72a5c90d20384576ab20b1a.jpg',
#  '/data/FaceScrub/Laurie_Metcalf/face/ebc75dac6aa04190cecaa15a2ad7ece91a5745f1.jpg',
#  '/data/FaceScrub/Denzel_Washington/face/f39c9dc50dbcd7c380ef86e137ac5756d0085da7.jpg',
#  '/data/FaceScrub/Neve_Campbell/face/7a1a6c006c302fe371b81c34f44b3c36874e2f99.jpg',
#  '/data/FaceScrub/Glenn_Close/face/975627eb34203ee18fd6c3babee59c50513babde.jpg',
#  '/data/FaceScrub/Kristen_Johnston/face/6d15624282368cf0aed026e6c7d6554a3f0f5328.jpg',
#  '/data/FaceScrub/Hank_Azaria/face/de10be296a3440f82a9d86af4247469e4787f3ce.jpg',
#  '/data/FaceScrub/Cary_Elwes/face/25580f0108604af0822fa126a5ddb36f147ca51f.jpg',
#  '/data/FaceScrub/Alfred_Molina/face/1648750698aec7b17b7a5ae92c9d8efe6a81ae38.jpg',
#  '/data/FaceScrub/Chris_Rock/face/a206fe74679c04f47c965e0a42fa3fd5749e3d07.jpg',
#  '/data/FaceScrub/Natalia_Livingston/face/4e68cd6fae1b6a39ee6c8e595bddce6fe5dab79a.jpg',
#  '/data/FaceScrub/Holly_Marie_Combs/face/fd56f1787db6fe5060328ecc3ead525a5a73526d.jpg',
#  '/data/FaceScrub/Robert_Redford/face/11b9511a88d826a13b920a0535425687ee433471.jpg',
#  '/data/FaceScrub/Diahann_Carroll/face/e9b680b7d2e02e6f77e82c48fbfd6ff00f2fe46d.jpg',
#  '/data/FaceScrub/Andrea_Bowen/face/c2970a192253393f965e1c6de6e9192b196dc52f.jpg',
#  '/data/FaceScrub/Burt_Reynolds/face/e154d4169b29b0a26a78f68c2d44cc23772318a8.jpg',
#  '/data/FaceScrub/Kristen_Johnston/face/c26d9916a81c93470cc4e4760d43a35fae38e872.jpg',
#  '/data/FaceScrub/Cary_Elwes/face/287e7dac527aabf72e8dc07e97349d1580b79f77.jpg',
#  '/data/FaceScrub/Matthew_Perry/face/a493f82cde7d00a973a6f9cf5e6cc442634753c7.jpg',
#  '/data/FaceScrub/Tia_Carrere/face/07ca7142d15e98d7b7776bb0789ca079efcd99bc.jpg',
#  '/data/FaceScrub/Charlie_Sheen/face/9db8644883df2b518a38862ff7466ea1de856bcf.jpg',
#  '/data/FaceScrub/Justine_Bateman/face/0d44906408bd3f7cfc8055b76463adcc33939e3d.jpg',
#  '/data/FaceScrub/Anthony_Hopkins/face/e02018833a9cfb15c585d729e48a608c35e64156.jpg',
#  '/data/FaceScrub/Roseanne_Barr/face/c52f1cb2d4e5f6ce774397db3b3e38e68f45c00f.jpg',
#  '/data/FaceScrub/Ben_Kingsley/face/18a2ce7199ec71da600738fd106b124ecedb3334.jpg',
#  '/data/FaceScrub/Martin_Sheen/face/07b591a6464ee565e4e0650f64e173c9db64bbb1.jpg',
#  '/data/FaceScrub/Neve_Campbell/face/372b5aac9800a0282f68e7d401dd5c06cf6f5ff3.jpg',
#  '/data/FaceScrub/Andrea_Bowen/face/123c576fb7fe4df3d89b0f1674e980cca153bb94.jpg',
#  '/data/FaceScrub/Victor_Garber/face/62234d63ad321a9d7fc6bc7e20d74f9b8baaf00f.jpg',
#  '/data/FaceScrub/Bill_Hader/face/af805e8dcb40bb032642e08f4040192a820b22a8.jpg',
#  '/data/FaceScrub/Tamala_Jones/face/41c4562091cd35f6ceaa6f71b53edce379a8ac92.jpg',
#  '/data/FaceScrub/Nicole_Eggert/face/b6f57fe3b3b71d9d3f3e7419b7ddee6c94cabbf9.jpg',
#  '/data/FaceScrub/Andrea_Bowen/face/0d0793b06f37b0044c291e194629d0e42b9789f5.jpg',
#  '/data/FaceScrub/Amaury_Nolasco/face/fd7388a6299bc4e08c9a3f02096f77a0c663688c.jpg',
#  '/data/FaceScrub/Farrah_Fawcett/face/5e63497906b00eb9f9483331c1e68536366c88fd.jpg',
#  '/data/FaceScrub/Tina_Fey/face/3578beee8e6aec22ac21324d58a40a868e8e5c2b.jpg',
#  '/data/FaceScrub/Luke_Wilson/face/31e3600c04eec7b4c0dda392d8c7a1de4bb13df5.jpg',
#  '/data/FaceScrub/Bradley_Cooper/face/44f2ae1a9ee5043cb6b71ac8cdb7d9cf4ca5f08b.jpg',
#  '/data/FaceScrub/Jessica_Capshaw/face/0ca2fba8878866a7ce49c5b23706a58eb06e33b9.jpg',
#  '/data/FaceScrub/Alan_Arkin/face/bd16c1d0dca286500069f1379d3b59071bd8dd2f.jpg',
#  '/data/FaceScrub/Sherilyn_Fenn/face/f208c2d045a20fd89a5216a6e0c57c4f1ff67de8.jpg',
#  '/data/FaceScrub/Dana_Delany/face/808929f734b4863e9ce54dfa727ec219c164c590.jpg',
#  '/data/FaceScrub/Chris_Rock/face/9e5263811ed3699da3062e82fd633f657a975588.jpg',
#  '/data/FaceScrub/Angell_Conwell/face/b8d16162e68256833b28aa3218a575711079d8e9.jpg',
#  '/data/FaceScrub/Chris_Rock/face/f006793dbe7d9074a9c476b60d40330bec22fb3d.jpg',
#  '/data/FaceScrub/Andy_Serkis/face/ffd08b3e4479fdfa66cc1a06cba98a40ddaac317.jpg',
#  '/data/FaceScrub/Neve_Campbell/face/5a0e1f34650b040db73c31b064ac08a0d15e1c9e.jpg',
#  '/data/FaceScrub/Yasmine_Bleeth/face/8aa86db785238e6f06054124cab8f19d57708158.jpg',
#  '/data/FaceScrub/Don_Cheadle/face/a34df95b91fed43baf9d0d2409b17f17ad394d06.jpg',
#  '/data/FaceScrub/Valerie_Bertinelli/face/39ba5176a8fe52847e4be12714a6584fadcb1e8c.jpg',
#  '/data/FaceScrub/Jesse_Eisenberg/face/5dc9e73f739f06a4d3b995f3114db9b9111b3028.jpg',
#  '/data/FaceScrub/Daniel_Radcliffe/face/79a8d87be2d8e0d28af9fca1ecec794a47a6b29c.jpg',
#  '/data/FaceScrub/Kal_Penn/face/25de4de3e8be4e22f97f937938d11699c6746e0c.jpg',
#  '/data/FaceScrub/Ben_McKenzie/face/d7b0cd077f1dd26b7318ec689ebf477e465c9797.jpg',
#  '/data/FaceScrub/Gene_Hackman/face/67a0e96eeeb03e82d9405f67cda180f67e158076.jpg',
#  '/data/FaceScrub/Richard_E._Grant/face/06272b135873c1ea8f1327561093b937e235cd62.jpg',
#  '/data/FaceScrub/Clive_Owen/face/7ba17d3a18acffd6261a54295a53f95f1be33a15.jpg',
#  '/data/FaceScrub/Rupert_Grint/face/ec264b22cf9b3ea026d9f3e69edb24e4cd9ae46a.jpg',
#  '/data/FaceScrub/Roseanne_Barr/face/6fd8371b83aaa5cdac2cafea012de0acb6c77e76.jpg',
#  '/data/FaceScrub/Brendan_Fraser/face/ab20c828319b87df8603b7d23363ad094ac2b25d.jpg',
#  '/data/FaceScrub/Joan_Collins/face/ad8fa1557799b099a530f96e4475baebfbeeeb90.jpg',
#  '/data/FaceScrub/Jeremy_Irons/face/811ce3c82f753b2168cb1075e51c264f0d576eb0.jpg',
#  '/data/FaceScrub/Christian_Slater/face/613f0de9d5a407d3ccbdc6cf6c9eb4c4e38ef593.jpg',
#  '/data/FaceScrub/Colin_Farrell/face/f10fede2c9a0b004f0882f2ff15183159104f9a1.jpg',
#  '/data/FaceScrub/Chazz_Palminteri/face/3f9ad19eba92ddac5b75f271eff3c1f74ffc35e8.jpg',
#  '/data/FaceScrub/Hal_Holbrook/face/5540024594b851379479f706516d632545a6ca51.jpg',
#  '/data/FaceScrub/Patrick_Warburton/face/240ed9cfef9b2d3e869dbd537d7cd7cd0e8fc371.jpg',
#  '/data/FaceScrub/Tamara_Braun/face/ea656fc8b72400c933d002aad4ae7939480d8068.jpg',
#  '/data/FaceScrub/Burt_Reynolds/face/44901b4697b91eafa3567605a0935267ade39284.jpg',
#  '/data/FaceScrub/Don_Cheadle/face/f8d5404ff5430da3bfaefba7338860713f00ef8e.jpg',
#  '/data/FaceScrub/Jonah_Hill/face/86e61816f0850ff61feb10bd4661140a72f4ef85.jpg',
#  '/data/FaceScrub/Edi_Gathegi/face/002a603f4d05176969e4b8a5d83ef07e118633ec.jpg',
#  '/data/FaceScrub/Lorraine_Bracco/face/356d5706867f23bb4421a33b0fda4e4079b27fce.jpg',
#  '/data/FaceScrub/Victor_Garber/face/d456205ce4df2db24ec37788f503df7a8e554a88.jpg',
#  '/data/FaceScrub/Jared_Padalecki/face/0af1ad2d4d677f23398bdd7662d7cc85b2befe0b.jpg',
#  '/data/FaceScrub/Bernard_Hill/face/61e878122edb907e51c29db1a82c63d4144434c2.jpg',
#  '/data/FaceScrub/Sherilyn_Fenn/face/379b211a70f7993cc1bc3f969531841d1a144e6c.jpg',
#  '/data/FaceScrub/Dustin_Hoffman/face/ec05071cebce651ea2e8ec437935f1ff63151611.jpg',
#  '/data/FaceScrub/Joan_Collins/face/a2a85ec0642ffcd08df0f17836e091fcc33e5d0f.jpg',
#  '/data/FaceScrub/Alfred_Molina/face/092fbaca73986c50d7f769857b6471dc1262dcb8.jpg',
#  '/data/FaceScrub/Chris_Rock/face/fb5f4d5d5021c444f450da3d46c02b4b43c09154.jpg',
#  '/data/FaceScrub/Jackie_Chan/face/9c6604a1c6bb7c2352de172f24ee66767440da32.jpg',
#  '/data/FaceScrub/Matthew_Perry/face/346f823e8976df607bd11c04adf3a8c4d2fb4716.jpg',
#  '/data/FaceScrub/Hector_Elizondo/face/b62181a0b4ff15b9d85d4533288bb1ad6f35a4aa.jpg',
#  '/data/FaceScrub/Amaury_Nolasco/face/874887832ee3914dfba818c035dacc7874088feb.jpg',
#  '/data/FaceScrub/Laurie_Metcalf/face/fba29cbc9d4d546bbf6cf590e757a88caf8a7a15.jpg',
#  '/data/FaceScrub/Robert_Pattinson/face/b36ad2eb5ef888a8f4025e672e0085022a284872.jpg',
#  '/data/FaceScrub/Shannen_Doherty/face/a325f574738e6dde420df60dc7932e84fa87f019.jpg',
#  '/data/FaceScrub/Tia_Carrere/face/3c02b920247403df84e581fb9210c201606e687a.jpg',
#  '/data/FaceScrub/Sarah_Michelle_Gellar/face/a366077dc97ece44df792c5c0bc6b212ff24f0c9.jpg',
#  '/data/FaceScrub/Kirstie_Alley/face/bb1a559fb894454b32a7c9680e96f0a4d144f9ce.jpg',
#  '/data/FaceScrub/Hank_Azaria/face/64f3d7a8e7f13ff07fea8be4eaf767d8d9f38e2b.jpg',
#  '/data/FaceScrub/Jonathan_Rhys_Meyers/face/d8e55150a4a59956b11ef5c6a1d11a084343522f.jpg',
#  '/data/FaceScrub/Amaury_Nolasco/face/08082678b3546ea3a3d3dc34f107e740913cbc35.jpg',
#  '/data/FaceScrub/Marcia_Cross/face/d19f2ad8ec12f08469e36f037cf06df4b84e33cd.jpg',
#  '/data/FaceScrub/Christel_Khalil/face/bf04b872c66a2cf1679e524142e9e631cc1250f5.jpg',
#  '/data/FaceScrub/Jared_Padalecki/face/7ecb271e17b5e2cd7a44cda85f58938189e2f77e.jpg',
#  '/data/FaceScrub/Cary_Elwes/face/eebdf18899fcbf80f1830ee7fbd3e5e40639332d.jpg',
#  '/data/FaceScrub/Victor_Garber/face/99ff7091e770d0fa161d6b25bd221f85230016dc.jpg',
#  '/data/FaceScrub/Jerry_Seinfeld/face/7367718f165882dd7bb8257e58e9c36d091d1ed8.jpg',
#  '/data/FaceScrub/Tempestt_Bledsoe/face/532e878ffe245377dbe51a2cc2afe97faf41c4ff.jpg',
#  '/data/FaceScrub/Debi_Mazar/face/1e04b062756b46d6a8c3f59c82909e0a2a0095d6.jpg',
#  '/data/FaceScrub/Jennette_McCurdy/face/49dc585fb527def213b0644ef3eb2dee77ee58a9.jpg',
#  '/data/FaceScrub/Lesley-Anne_Down/face/11324dcffcf682f35ae1fb5e54f68a273bd840ef.jpg',
#  '/data/FaceScrub/Jeanne_Cooper/face/7f5bc31aa963513247373fb170724c27fddfea5f.jpg',
#  '/data/FaceScrub/David_Cross/face/bf92eef9791d60bc00e838290aafe1297b387a8a.jpg',
#  '/data/FaceScrub/Tina_Fey/face/a29ec636bd7d662665e4f3cf706af416e86f0960.jpg',
#  '/data/FaceScrub/Yasmine_Bleeth/face/fefef48784fac432697f55cc3b41bb558bf2f5ea.jpg',
#  '/data/FaceScrub/Billy_Zane/face/ac9b39348b2b7d8548455e8bdb6fb3870a0b4ba8.jpg',
#  '/data/FaceScrub/Josie_Bissett/face/38e7b07306748b81283cc3525a70a2bd21936f19.jpg',
#  '/data/FaceScrub/Gates_McFadden/face/9d992c48be76d3d36101ad4d0ceb077eeda3303e.jpg',
#  '/data/FaceScrub/Josh_Brolin/face/8e0bba21b8aa428342e1a4282afdb40596b7b974.jpg',
#  '/data/FaceScrub/Miranda_Cosgrove/face/50a07b7f495051e5d2095d36b438fbb4a789e269.jpg',
#  '/data/FaceScrub/Glenn_Close/face/5bd4904126e790421768831466e9257e79bde151.jpg',
#  '/data/FaceScrub/Jake_Weber/face/b518e811fc108607bd0551b758a0339265a067e2.jpg',
#  '/data/FaceScrub/Neve_Campbell/face/00a244825221523a76b325ee6bd1ab4680878ef8.jpg',
#  '/data/FaceScrub/Sarah_Michelle_Gellar/face/c748a3f16d61b407dd2dc8cbee18f9963327dd3c.jpg',
#  '/data/FaceScrub/Jim_Carrey/face/652b59dc92ed30f42fe3f12ee7cfae6788a5f8e3.jpg',
#  '/data/FaceScrub/Mel_Gibson/face/120f79e1ea33be887b074fb9ceb5e69dc3b55361.jpg',
#  '/data/FaceScrub/Brendan_Fraser/face/7c9cfca1dfbddf57fd5a46927b78c1ac9c75880a.jpg',
#  '/data/FaceScrub/Peter_Sarsgaard/face/58c4048a73f47debe70a57e1d2c6edf546d19d8e.jpg',
#  '/data/FaceScrub/Tamala_Jones/face/dadd339edf5700d351a8b6be9de7afc6570a7e5f.jpg',
#  '/data/FaceScrub/Sasha_Alexander/face/3187a7ccb3d2ba634e977ea5c9446e6b5b47d51d.jpg',
#  '/data/FaceScrub/Charlie_Sheen/face/08efc62b3b3c32e2ea28ddd1549a6a9a671c355c.jpg',
#  '/data/FaceScrub/Charlie_Sheen/face/09455c4ef40adbc68b8ce96a87d4497a0e08e7d8.jpg',
#  '/data/FaceScrub/Anne_Hathaway/face/471f59d10040e77c299159b1300ec54b94814335.jpg',
#  '/data/FaceScrub/Hank_Azaria/face/04eb7b1bed88a17baefd9db327a0d3edc3e19cb2.jpg',
#  '/data/FaceScrub/Dan_Lauria/face/123bcd577623380f17589c70cae3d30ecba01c6f.jpg',
#  '/data/FaceScrub/Kirstie_Alley/face/3b019d7bdcd6149f9ac4737b64f7695ee7984dab.jpg',
#  '/data/FaceScrub/Zooey_Deschanel/face/38a0ead5d0af0919cfa9e0aa5955190aa59ba7df.jpg',
#  '/data/FaceScrub/Alfred_Molina/face/fdd8713ba5717b483c6d56d537b64e84e8dffc16.jpg',
#  '/data/FaceScrub/Melina_Kanakaredes/face/6133f1e8aea248fd7625d45077e476037c89f3eb.jpg',
#  '/data/FaceScrub/Cary_Elwes/face/3b5c4b9f194eb4aad68e45dc90d51bcc16bd31e1.jpg',
#  '/data/FaceScrub/Jonah_Hill/face/c3a50a9d2711e7500beaf1132f8da61906d89ec5.jpg',
#  '/data/FaceScrub/Bill_Hader/face/f059035864819cbb9da9e83dcad1299c49c47ecb.jpg',
#  '/data/FaceScrub/Jon_Voight/face/4bbbe87675fd11ff55f29866d026016db4567a89.jpg',
#  '/data/FaceScrub/Clive_Owen/face/984de671bf2e8ee9e3d988e3ba44f49f8f2e4fac.jpg',
#  '/data/FaceScrub/Gene_Hackman/face/cea116107379ac20e8991855f438a72895a407e9.jpg',
#  '/data/FaceScrub/Ryan_Reynolds/face/68338d60bcc0536bc5edfa6ca93b1bf757d8bb46.jpg',
#  '/data/FaceScrub/Tina_Fey/face/96f4dd73c52a1514d407506c90182ede16abc80b.jpg',
#  '/data/FaceScrub/Robert_Pattinson/face/6c206be3142a5a32d4f5e2a822f95f0efc91c666.jpg',
#  '/data/FaceScrub/Danica_McKellar/face/d735f26c200e69ce7d87fe94d635367e58968590.jpg',
#  '/data/FaceScrub/Sasha_Alexander/face/0a28dd301b49fb601cdf4cdf49c93ca8ce4edc61.jpg',
#  '/data/FaceScrub/Susan_Lucci/face/8afb98af9b44f4a218c573635089508d862c3719.jpg',
#  '/data/FaceScrub/Kal_Penn/face/0e024e21b0787a903a9fa4746b2c9ce6cc994855.jpg',
#  '/data/FaceScrub/Hector_Elizondo/face/eff6dad5efbea71f655918b01a546a65bcf9467d.jpg',
#  '/data/FaceScrub/McKayla_Maroney/face/8914785e8ce480691083bf5e026143fea669e267.jpg',
#  '/data/FaceScrub/Tempestt_Bledsoe/face/4dcfcf599e3e130ae06882e4a6c2f418fe9ad88a.jpg',
#  '/data/FaceScrub/Jean_Reno/face/2214edb292d920d5832ec018d2cf8dfd421aa1f1.jpg',
#  '/data/FaceScrub/Jonah_Hill/face/7e166b858fae69e0e9b8af5d3bd5f9d4211c26d3.jpg',
#  '/data/FaceScrub/Morena_Baccarin/face/34f162acc88396e55155992e885d7b966ea0ffae.jpg',
#  '/data/FaceScrub/Matt_Dillon/face/a2afd47301af905992fd26af74dfb80ad3d5d30c.jpg',
#  '/data/FaceScrub/Dustin_Hoffman/face/3f5d4cad6629c536962733268ce849fe368e490a.jpg',
#  '/data/FaceScrub/Patrick_Dempsey/face/919d08468c09e8f02709461537d83081de22fae6.jpg',
#  '/data/FaceScrub/Jesse_Eisenberg/face/c20be7687110f8d8c53b735746d0f9da6c52f864.jpg',
#  '/data/FaceScrub/Glenn_Close/face/3d62d0244fcc98c25e6d453f354acc9000262815.jpg',
#  '/data/FaceScrub/Ryan_Reynolds/face/7a4b97fc2f9e1f3b5e8aeb0b26cde9a64ba5fa25.jpg',
#  '/data/FaceScrub/Kerr_Smith/face/b50bf2e673436b399f3813b91303a89477ec2a4d.jpg',
#  '/data/FaceScrub/Tina_Louise/face/30c0a9008235c680c3827ae77d3497cf5136cf7d.jpg',
#  '/data/FaceScrub/Adrien_Brody/face/b8e47743604c03225d4b7d0cd2efb2033fc2e740.jpg',
#  '/data/FaceScrub/Dustin_Hoffman/face/3756950bdfe92ba881576bc7a68004f7fb580ebd.jpg',
#  '/data/FaceScrub/Patrick_Warburton/face/d3625c3160a10dc409fb434d47f04a612e5f3ee7.jpg',
#  '/data/FaceScrub/Diahann_Carroll/face/1fa77e716ce6ba62fe9f5f390b9c5a3cba8915a7.jpg',
#  '/data/FaceScrub/Angie_Harmon/face/de1f28b2ad520776a59a9d0f2d9a28b7be2a610d.jpg',
#  '/data/FaceScrub/Nicole_Eggert/face/f6255259e692da09605dc93f4da3d81df313d06b.jpg',
#  '/data/FaceScrub/Bernard_Hill/face/91d5312a3526490fbaa2b1d0d24187387e658807.jpg',
#  '/data/FaceScrub/Elizabeth_Berkley/face/fcc38d85975be906bd15bedc4d32bdad5a5fd2b3.jpg',
#  '/data/FaceScrub/Hector_Elizondo/face/31c0df2a11784d237feb27853f1be9dcba0aaa8d.jpg',
#  '/data/FaceScrub/Susan_Lucci/face/6e2f50a83b1268e6d2803cfbd68537716754941f.jpg',
#  '/data/FaceScrub/Richard_E._Grant/face/89c70434c25cc3ce03a92441564610b6b1f1eccb.jpg',
#  '/data/FaceScrub/Roseanne_Barr/face/79625c75980d3e683d3de9aef80073519a45f264.jpg',
#  '/data/FaceScrub/Matt_Dillon/face/28e72ca6c2fd993479ce9736e53d91948316c073.jpg',
#  '/data/FaceScrub/Kit_Harington/face/af48e6730132ac1d68dae1b6d55e459906ef0db1.jpg',
#  '/data/FaceScrub/Josh_Duhamel/face/f398fe672b33f9d3f32312e6e1a83dee720dc917.jpg',
#  '/data/FaceScrub/Billy_Zane/face/9d1f82dc2a781bcb410f2dd93bb9e57b4f5cc5bd.jpg',
#  '/data/FaceScrub/Farrah_Fawcett/face/2980c8b4f1d38f35a2b495506c12544dd9539fc6.jpg',
#  '/data/FaceScrub/Ben_Kingsley/face/4b471f61a0b3b807a4d864281686f68086322f61.jpg',
#  '/data/FaceScrub/Portia_Doubleday/face/c48d9c61b7e485c3efbbd73da476dcd81c2c2f38.jpg',
#  '/data/FaceScrub/Ashley_Benson/face/45500e0bf33419493af6b8a1652a8478f6c841bd.jpg',
#  '/data/FaceScrub/Zooey_Deschanel/face/2a14050c575562136ad2dbec651d1321a0b1e9d8.jpg',
#  '/data/FaceScrub/Robert_Downey_Jr./face/5f32858ed41518c68cd1b83f203438b57c420037.jpg',
#  '/data/FaceScrub/Kerr_Smith/face/32c14a046736265663ad96643a18f6160f1fe7d8.jpg',
#  '/data/FaceScrub/Hank_Azaria/face/090da46f878a46ad79152b846071f7cbc0125b60.jpg',
#  '/data/FaceScrub/Holly_Marie_Combs/face/ac687514333ff78e78d3fc93344c605d5b1cd57e.jpg',
#  '/data/FaceScrub/Andy_Garcia/face/2f735524e9f27270fa655b49cea47c0a53ef5a8f.jpg',
#  '/data/FaceScrub/Robert_Downey_Jr./face/64152010477fa6c1a2573e16cd7b8788816238de.jpg',
#  '/data/FaceScrub/Jeffrey_Tambor/face/eea9adf31865521214a057458368cb97c7182eea.jpg',
#  '/data/FaceScrub/Jackson_Rathbone/face/367442f595604ed9d2b5bd7b4602694fc82ca158.jpg',
#  '/data/FaceScrub/Ian_McKellen/face/ccaa35ee4bc2fc3e6283ca92f30f46ca004d8d19.jpg',
#  '/data/FaceScrub/Dana_Delany/face/1beed5755650b9911b5561df7df48968c972cdc3.jpg',
#  '/data/FaceScrub/Gene_Hackman/face/e93c0a2e54ae13b84fcc0589273b7158da9458a7.jpg',
#  '/data/FaceScrub/Omid_Djalili/face/c47a2e37b01a3cc579a62c41bcc1350a97b60993.jpg',
#  '/data/FaceScrub/James_Brolin/face/fae7e209776c4fd32f15ca370a3ae241a44ec432.jpg',
#  '/data/FaceScrub/Natalia_Livingston/face/1e14b9ca67e67084364711ba46b07234989660fb.jpg',
#  '/data/FaceScrub/Lisa_Kudrow/face/e9eea9976534117500f434ecaae7c31865db11a0.jpg',
#  '/data/FaceScrub/Rachel_Dratch/face/c0de65b8a3e01e7df137125a6e61a9ff146035f6.jpg',
#  '/data/FaceScrub/Dana_Delany/face/6e3dc27f6eaddb779b8e268c2b01bfb119ccda83.jpg',
#  '/data/FaceScrub/Jessica_Capshaw/face/0c222e50501c3c7d439da35fe549aead14af6535.jpg',
#  '/data/FaceScrub/Josie_Bissett/face/e69cf20dc0a057f769dad17cba95f313aa8112c3.jpg',
#  '/data/FaceScrub/Daniel_Radcliffe/face/400ae98462ac278b5ba6a9064ea60d439a72601b.jpg',
#  '/data/FaceScrub/Jason_Biggs/face/569c1126b169664c42933a4b6a6f1086dedc6327.jpg',
#  '/data/FaceScrub/Denzel_Washington/face/bf72584e3399a2aa53fe4734f7601e8cfd7ca9a2.jpg',
#  '/data/FaceScrub/Chris_Klein/face/2b1e6e91425ab7e1f3d78644bc5f653a951dd629.jpg',
#  '/data/FaceScrub/Luke_Wilson/face/ea15df18beeb4be364be6253f1e69949c68a7fe7.jpg',
#  '/data/FaceScrub/Margaret_Cho/face/e1ff318dac683c47ffb15975f05d5dfb5a09fd38.jpg',
#  '/data/FaceScrub/Daniel_Radcliffe/face/6938a53549f35bf1a091c5b1f373f446248443b0.jpg',
#  '/data/FaceScrub/Brendan_Fraser/face/0519bb00da41afd2435ddab056e5f3830dcd8727.jpg',
#  '/data/FaceScrub/Angell_Conwell/face/d00b7b5df4927d1823bd23aa56b6d5e215df235a.jpg',
#  '/data/FaceScrub/Jessica_Capshaw/face/37637a7632ee2e007a3d4a7b72991e761fd9c435.jpg',
#  '/data/FaceScrub/Selena_Gomez/face/2d58e58de0eda4674e426d9a1cab166e05994598.jpg',
#  '/data/FaceScrub/Jeffrey_Tambor/face/0f5c1e2d2ccf9385bec8839f9c14a79462ab760f.jpg',
#  '/data/FaceScrub/Angell_Conwell/face/94abe338791a3b9ef3f78262afa914ccced5afc6.jpg',
#  '/data/FaceScrub/Tatyana_M._Ali/face/01b13bc057b92e2bbc6ef0f6e7a86627a49f2ee6.jpg',
#  '/data/FaceScrub/Jonah_Hill/face/ca9cd83aa1f22071063cd72351d761067b8fc4b7.jpg',
#  '/data/FaceScrub/Kirstie_Alley/face/9b4fefa532964e5539e137d196258061cea2d8d0.jpg',
#  '/data/FaceScrub/Sarah_Michelle_Gellar/face/18ecd7d94a50f3a6215ded8f0090c08bf5694b84.jpg',
#  '/data/FaceScrub/Audra_McDonald/face/8b26cae66c8cb35405e76c3ebcc531de311896e8.jpg',
#  '/data/FaceScrub/Robert_Redford/face/e141edd19e8627344994451145a01ece08e3454d.jpg',
#  '/data/FaceScrub/Mark_Wahlberg/face/c0d7221ee14ce3cafdaf66bffe3b5da52e0f68c6.jpg',
#  '/data/FaceScrub/Portia_Doubleday/face/9416246944b08694704d8f33b58a2a1bd5abdc5f.jpg',
#  '/data/FaceScrub/Jessica_Capshaw/face/2c672356082186e9f62c5ef03fd5770f37c432f7.jpg',
#  '/data/FaceScrub/Josh_Brolin/face/03f16fa0947ac89e3363d03813481debe2d22560.jpg',
#  '/data/FaceScrub/Billy_Zane/face/24280049f11d07c53eff59667d686e8da02db94f.jpg',
#  '/data/FaceScrub/Lisa_LoCicero/face/c51a1e27d492c1b6ad331100d35cdf6b0b93913e.jpg',
#  '/data/FaceScrub/Angie_Harmon/face/c89487f9cfc131701f32b63d0447951b4fbdd8d6.jpg',
#  '/data/FaceScrub/Jason_Biggs/face/8fe109299220897961f16b8f8d611d581d2e971a.jpg',
#  '/data/FaceScrub/Patrick_Warburton/face/85b092f151273e83cb5e71239527c8e888781565.jpg',
#  '/data/FaceScrub/Bill_Cosby/face/9c15bb969d1d468d7d517f3d4dea715f7136f241.jpg',
#  '/data/FaceScrub/Ryan_Reynolds/face/55d3d5532023e5e823f5c2edd161a6136dd77630.jpg',
#  '/data/FaceScrub/Channing_Tatum/face/271cbc65c187390076e150ea35039edca44d5deb.jpg',
#  '/data/FaceScrub/Jesse_Eisenberg/face/627d48b75bbe4329699b2bf8030bf2f84a32c765.jpg',
#  '/data/FaceScrub/Lesley-Anne_Down/face/1334510d5337bbf420e0b3b46324db5b488ba102.jpg',
#  '/data/FaceScrub/Jonah_Hill/face/abc6621c427a66b0f05277adb68b69711fd34946.jpg',
#  '/data/FaceScrub/Roseanne_Barr/face/5b05f6262ee35d5ae538b570d8b0f46365610ebd.jpg',
#  '/data/FaceScrub/Mayim_Bialik/face/de3c08edf98bbb09749ff91124aa7df6e08337e1.jpg',
#  '/data/FaceScrub/Glenn_Close/face/504bb7ab46d34af9f172dd0d8364f97320a5f010.jpg',
#  '/data/FaceScrub/Dustin_Hoffman/face/0acc66bf52306bf448a444a01cd29e01205f0d86.jpg',
#  '/data/FaceScrub/Jason_Biggs/face/584cd98c2f2193a07733e74a5bd809bab592d4dc.jpg',
#  '/data/FaceScrub/Chris_Kattan/face/84ca56c211095d8b65ea8c00b7d6eb431eb6c06a.jpg',
#  '/data/FaceScrub/Margaret_Cho/face/f5e76a33b289c74e16c75db9eca3d71078c8dd22.jpg',
#  '/data/FaceScrub/Billy_Zane/face/b4891915f3499b27a541b1f2d974a9f047fc99d6.jpg',
#  '/data/FaceScrub/Tina_Fey/face/b55df073461cee83015db48aeb691e70e30bfe7a.jpg',
#  '/data/FaceScrub/Angie_Harmon/face/a7b3541f9dfe387338d381c1baead26ca054798f.jpg',
#  '/data/FaceScrub/Jonathan_Rhys_Meyers/face/72106245757e3458c29729a667f196af42fcfdaf.jpg',
#  '/data/FaceScrub/Jerry_Seinfeld/face/7f3526b9bc936c63e0568f8ecbc417f9c0ae27b8.jpg',
#  '/data/FaceScrub/Richard_E._Grant/face/fc6ed3b9de2977751693293eab84a89cd5b8d09b.jpg',
#  '/data/FaceScrub/Jeffrey_Tambor/face/8b8fde1a809a516a7743a2e19728800dd96e4544.jpg',
#  '/data/FaceScrub/Jessica_Capshaw/face/ec0e406e71fa784805bc364d0f3240e6fbca5c4f.jpg',
#  '/data/FaceScrub/Jim_Carrey/face/d40db014ae549f0bbf4ef3db6ad27240fad248f9.jpg',
#  '/data/FaceScrub/Cary_Elwes/face/947a88d4e3deefb2b286f9d2befb8dbbaf9aaf03.jpg',
#  '/data/FaceScrub/Andy_Serkis/face/5cff2e2541409a6775a68a48dec1fbe5de7eadf8.jpg',
#  '/data/FaceScrub/Robert_Downey_Jr./face/2f0cc8fb5e0a5dba7d30466114927a103d133c34.jpg',
#  '/data/FaceScrub/Bill_Hader/face/5ed35e0b2576eaeea80f8637698fe5a86b1359ae.jpg',
#  '/data/FaceScrub/Robert_Downey_Jr./face/2e460862b294634f0e90728af238696765493ce1.jpg',
#  '/data/FaceScrub/Adam_Brody/face/f6b28230501fb793b00a315ba3360766de96dcac.jpg',
#  '/data/FaceScrub/George_Clooney/face/e73c51f61d98ff98f48b980f9bc1651ee3481c77.jpg',
#  '/data/FaceScrub/Jessica_Capshaw/face/615a65bb649e21ac9eb4d89c61506109fbbc00e3.jpg',
#  '/data/FaceScrub/Heath_Ledger/face/0dd7dd4ec70a9ab96b3ef93dff52cf86efde5fb4.jpg',
#  '/data/FaceScrub/Neve_Campbell/face/d5f521111d89d4265bc7d252a21df12484ca5ac1.jpg',
#  '/data/FaceScrub/Valerie_Bertinelli/face/97269ad2cb7da243ed93cae99c10573b232c20b4.jpg',
#  '/data/FaceScrub/Dan_Lauria/face/382d188387a93922fd7c8130b9c73121fc476602.jpg',
#  '/data/FaceScrub/Ashley_Jones/face/bea8301b38b011795fe8c6cebfb5b0f4b553b345.jpg',
#  '/data/FaceScrub/Bradley_Cooper/face/2dbbe1a9eb736c92d13b6c2bd08044f0049870ae.jpg',
#  '/data/FaceScrub/Andrea_Bowen/face/7d53048574c517142380e9c13807cb2be4f9f42f.jpg',
#  '/data/FaceScrub/Elijah_Wood/face/02512a0baf7243d881c0b45224163c073d803de3.jpg',
#  '/data/FaceScrub/Sherilyn_Fenn/face/2919963460a49fe8be89222af424fd2b5badeec4.jpg',
#  '/data/FaceScrub/Andy_Richter/face/7c4d0a9c29c27dcd1469722fe486b0452f62356f.jpg',
#  '/data/FaceScrub/Matthew_Perry/face/08ee89c8e6031dc22bb9803ead0259f6cc121cd2.jpg',
#  '/data/FaceScrub/Elizabeth_Berkley/face/4b9cb8dd73d598839414e8918e9224f345226520.jpg',
#  '/data/FaceScrub/Christel_Khalil/face/3187f464d348be985e63eb9a9e61d78c294ee2b2.jpg',
#  '/data/FaceScrub/Neve_Campbell/face/9c9d83d8449bb80520fe94fab6aeadd63cdbef23.jpg',
#  '/data/FaceScrub/David_Boreanaz/face/61fb5f574cc30eb54a6d0ca27f64041ad9451678.jpg',
#  '/data/FaceScrub/James_Brolin/face/5cf41832adcf0e39d7e96ace86f37ca153a4f1bf.jpg',
#  '/data/FaceScrub/Annie_Ilonzeh/face/52cc9e0499fb36dcb4aa03c43d243524030ec2ad.jpg',
#  '/data/FaceScrub/Annie_Ilonzeh/face/ce65a07cb6ac05f535a95c6b82b49a6e08537b87.jpg',
#  '/data/FaceScrub/Glenn_Close/face/7f42a1c6975fe0fa598dd7b83e29e33417434f96.jpg',
#  '/data/FaceScrub/Clive_Owen/face/ebfc13fc719f7c84285f33ed08691742da1ec7ff.jpg',
#  '/data/FaceScrub/Ken_Watanabe/face/1fa410715c0baf582cc2e9c6b8dcdf440881d6f1.jpg',
#  '/data/FaceScrub/Josh_Duhamel/face/382d95ba305ca35e7d6a6f85ba18b0f2caba3095.jpg',
#  '/data/FaceScrub/Selena_Gomez/face/ee442e7e8ab87bb7a17602d80a0e3ff6bb04a725.jpg',
#  '/data/FaceScrub/Benicio_Del_Toro/face/042cafd7f119696434b73103665dbb9cd77d920f.jpg',
#  '/data/FaceScrub/Josie_Bissett/face/d7ed2b9c2600f5c1874d270b1005bbb5c9c12427.jpg',
#  '/data/FaceScrub/Debi_Mazar/face/62a05acbf235d2b0e0be81f02440f9d0b62832ec.jpg',
#  '/data/FaceScrub/Matthew_Perry/face/30492086748d380fca15605742fa7b1a870d394f.jpg',
#  '/data/FaceScrub/Diego_Luna/face/62d201088eab8d3e23d1830a04f5c96c150c308b.jpg',
#  '/data/FaceScrub/Rupert_Grint/face/cc595295ace7be80c7c1b882c5f5ebdb1c1add5f.jpg',
#  '/data/FaceScrub/Jason_Biggs/face/f50720e04aef141dc703e70ad9e1fafd8c5e97ee.jpg',
#  '/data/FaceScrub/Billy_Zane/face/40cf1db717d411f1c2ec4ca6855a5e5ee068267f.jpg',
#  '/data/FaceScrub/Audra_McDonald/face/192fe6f234162125cca7692d99821062140bf0b8.jpg',
#  '/data/FaceScrub/Jim_Beaver/face/424f753d8a1c073232081f1f1cbe1019ce480572.jpg',
#  '/data/FaceScrub/Matt_LeBlanc/face/1cdc01c1915cae492d3f349a4eb130c396b6c3b5.jpg',
#  '/data/FaceScrub/Christian_Slater/face/4bb7204fd1a452ade86569777732db8304fba167.jpg',
#  '/data/FaceScrub/Danica_McKellar/face/d9424a372adc894a9942d9ce7b83365680924585.jpg',
#  '/data/FaceScrub/Anthony_Hopkins/face/c83bebd265aa2e863272338b05c2ec76ca1ec945.jpg',
#  '/data/FaceScrub/Diego_Luna/face/414ff18f088e861003ba5abf1a93f219b953ce6d.jpg',
#  '/data/FaceScrub/Anthony_Hopkins/face/91cdf4dc9b1d74fd1186d2a7876b1c4ef023d33f.jpg',
#  '/data/FaceScrub/Jeffrey_Tambor/face/a1317857452d14241758302566bb6a10d853062c.jpg',
#  '/data/FaceScrub/Lisa_Bonet/face/7c75356c912f0f774296d0a2c8a46d0c5a384d4f.jpg',
#  '/data/FaceScrub/Christian_Slater/face/3dfa743cf15ea0fc6303518afd59e7533ba5de9b.jpg',
#  '/data/FaceScrub/Amaury_Nolasco/face/48d824a9633ec9a6c58f16c4260461b255c7ec96.jpg',
#  '/data/FaceScrub/Lisa_Bonet/face/11fc689873472f5e605feb14cd63b654f8881013.jpg',
#  '/data/FaceScrub/Jake_Gyllenhaal/face/e27335fec83e5c64592cc44435585fa8f30c6ded.jpg',
#  '/data/FaceScrub/Peter_Sarsgaard/face/76a61a50b38b9153aa40ea9e8d2b179eafa3747e.jpg',
#  '/data/FaceScrub/Andrea_Bowen/face/0c29a6952c3a22c7c0e6593039e4cde34e36a41d.jpg',
#  '/data/FaceScrub/Jennette_McCurdy/face/2e2f255fb825960d18f87f9baec288d628a7e814.jpg',
#  '/data/FaceScrub/Omid_Djalili/face/15a606d88bb8c3c1bb52ac317257d6062b534304.jpg',
#  '/data/FaceScrub/Eliza_Dushku/face/6ee32c9877922011d55f8c5478440cd0253d83a6.jpg',
#  '/data/FaceScrub/Omid_Djalili/face/dce0811a6c4872a660abe888d2b89be53e27df97.jpg',
#  '/data/FaceScrub/Richard_Gere/face/0f77e8d550204c48e551abf4b6b05aab7e089873.jpg',
#  '/data/FaceScrub/Christian_Slater/face/46b3bef14e7a75586a4e19dc15792458b8c7b81a.jpg',
#  '/data/FaceScrub/Nicolas_Cage/face/ea50ac17ec08341bcda7c5e5792d80953facdb87.jpg',
#  '/data/FaceScrub/Daniel_Radcliffe/face/eab87bb32f27be37f41319be1a396b51fceebc27.jpg',
#  '/data/FaceScrub/Jonathan_Rhys_Meyers/face/3de5884d61cde321511ddbce2d1e846cd3b73a6b.jpg',
#  '/data/FaceScrub/David_Boreanaz/face/a416a858cbf0981a1ba05100370c0808aceb7f0e.jpg',
#  '/data/FaceScrub/Tamala_Jones/face/fd69cc1109bdc7551a87824bb2ca56b45fe956a2.jpg',
#  '/data/FaceScrub/Karl_Urban/face/56b6ad041672c09589ba871865e3b05bccb6349c.jpg',
#  '/data/FaceScrub/Josh_Duhamel/face/4ac1281bea8db392f82d4b5771f2a0fe0b542a10.jpg',
#  '/data/FaceScrub/Colin_Farrell/face/16dc4589370484da6624049ef028733368c32200.jpg',
#  '/data/FaceScrub/Diahann_Carroll/face/bbe70def88bc1da969378ffa33f55ed1e284aa4b.jpg',
#  '/data/FaceScrub/Rupert_Grint/face/01677aa0faf6d5133752e0686b9352c63d5a2896.jpg',
#  '/data/FaceScrub/Bernard_Hill/face/9aa11f3a215ae5416d06d58b592bb6606fcc74e8.jpg',
#  '/data/FaceScrub/Diego_Luna/face/c6f906013ee605962619cf4ee96c9aaeaf71b0cc.jpg',
#  '/data/FaceScrub/Jeffrey_Tambor/face/cdd656175b3b16a7bd6a22636c0efc80f8ffe00e.jpg',
#  '/data/FaceScrub/Kristen_Johnston/face/81cb4679b8b0dfc210ba0f877f1fe9cede62f751.jpg',
#  '/data/FaceScrub/Kristen_Johnston/face/0d1e49cd8fc42fb47d1ec4c56b2c9d59535a0901.jpg',
#  '/data/FaceScrub/Jessica_Capshaw/face/020963141edd07e1a7b512fbd70e08060f2702ce.jpg',
#  '/data/FaceScrub/Matt_Dillon/face/089ec51407b3938d8db399b75e6a2993d4b610c7.jpg',
#  '/data/FaceScrub/Andy_Richter/face/d4fdd60718e398454f2427d5ba16151b22b205b0.jpg',
#  '/data/FaceScrub/Susan_Lucci/face/762d9ae474f692f11fd62db1c16910632d3f1147.jpg',
#  '/data/FaceScrub/Patrick_Warburton/face/670cb453238347a9e0ba5cfecda08d74feda24f7.jpg',
#  '/data/FaceScrub/Alyson_Hannigan/face/ce94f70c4afd9044c4281a6741656c6abd2dcf2f.jpg',
#  '/data/FaceScrub/Sasha_Alexander/face/6740ad9fe51e2e5f7d7fa19a716f156945c0d072.jpg',
#  '/data/FaceScrub/Sarah_Michelle_Gellar/face/14eed5afcb0410956145ccb67dddbf8c2542a0ea.jpg',
#  '/data/FaceScrub/Anthony_Hopkins/face/23b6c2c608f1283baff9549148c3af88eb52edf6.jpg',
#  '/data/FaceScrub/Adam_Brody/face/a0c14d6b9eb735a43ce76754e0b1ad9569717d28.jpg',
#  '/data/FaceScrub/Jean_Reno/face/b808cf9b391c4b337ffc63bcbea20092619c6538.jpg',
#  '/data/FaceScrub/Tempestt_Bledsoe/face/1daa8c8610baf18c7e5357dcc8e94491b40b7e90.jpg',
#  '/data/FaceScrub/Kirstie_Alley/face/bd6adf6b921f29f5e9f4640cdca61fac0b822ce9.jpg',
#  '/data/FaceScrub/Roseanne_Barr/face/c1d5cc2a0cbea0a9342c3b87471cedc2fc168f96.jpg',
#  '/data/FaceScrub/Andy_Richter/face/2b598df8140607f004fc63156c1bd7dd139728f2.jpg',
#  '/data/FaceScrub/Jesse_Eisenberg/face/8d20dce0b09a7dadb77542b7ec8005a9b6efc9aa.jpg',
#  '/data/FaceScrub/Susan_Lucci/face/87f10459ca415f5b9aa778347ab7bf38f3406660.jpg',
#  '/data/FaceScrub/John_Cusack/face/60b65898805e6be5bab78a9e8c27c9cadd7972d5.jpg',
#  '/data/FaceScrub/Robert_Redford/face/d6604f861cabf5fcd23f0a9d1a09e5c065efa599.jpg',
#  '/data/FaceScrub/Woody_Allen/face/51c47f2a8d23e59d74cb650e4cb8bfae5ec858ce.jpg',
#  '/data/FaceScrub/Tina_Louise/face/610956ae8ca5018f6a2691ff5bc89dae214ef94b.jpg',
#  '/data/FaceScrub/Mackenzie_Aladjem/face/56326e43ded76b59438869c0b40f7ed1f1c88f10.jpg',
#  '/data/FaceScrub/Ben_McKenzie/face/1b70dad960ebdcad56a63b13e452174dfadc005d.jpg',
#  '/data/FaceScrub/Hal_Holbrook/face/294559591d9c0bfc7a13b4cc697e89280e685694.jpg',
#  '/data/FaceScrub/McKayla_Maroney/face/05e2a15291f7ab0aa1bf0086f61ab86ec9a37d0f.jpg',
#  '/data/FaceScrub/Marcia_Cross/face/fac037acb8dda00c5119aeb9089379e354114eb3.jpg',
#  '/data/FaceScrub/Bill_Hader/face/2d4d56395f0ee9f48878db4a77c09ca30a36c3ca.jpg',
#  '/data/FaceScrub/Elijah_Wood/face/256cc3b2669260d0b623ffc4909aecc7a38b63b2.jpg',
#  '/data/FaceScrub/Karl_Urban/face/a6485903e7465877119d71632d570fdcf9591f39.jpg',
#  '/data/FaceScrub/Sherilyn_Fenn/face/600e451f5578ff14bad74f3513784a22b8151690.jpg',
#  '/data/FaceScrub/Adrienne_Barbeau/face/611957fb3b47a2d3f50aadc2c5a9666f784df588.jpg',
#  '/data/FaceScrub/Holly_Marie_Combs/face/885cf8feabbd1c8177251348a77142a0e14af2a6.jpg',
#  '/data/FaceScrub/Anthony_Stewart_Head/face/fb589107844266f4dd26ec2a2afcd8aa07c7e4b8.jpg',
#  '/data/FaceScrub/Jessica_Capshaw/face/ef45aaeb72e0bcff9e4ba87b26d652089d712d88.jpg',
#  '/data/FaceScrub/Nicole_Eggert/face/9b861a58e4cadf354dc439ee1c108256679c256e.jpg',
#  '/data/FaceScrub/Justin_Timberlake/face/a22922fda262097fa088caf96565d949c50bd1b7.jpg',
#  '/data/FaceScrub/Jennette_McCurdy/face/684428090a32a396220e7f363a13f25e9f456105.jpg',
#  '/data/FaceScrub/Kerr_Smith/face/af527eb90b0f48ff2c7a806ce07a4b879b8c9a80.jpg',
#  '/data/FaceScrub/Martin_Sheen/face/2d3bebce75b81244526b7ec282b6f94fd355875c.jpg',
#  '/data/FaceScrub/Nadia_Bjorlin/face/bb70cf9f067774effb26c9d5b104dc500008076c.jpg',
#  '/data/FaceScrub/Richard_Gere/face/465c3b5078eb5861ee0d97123cf60e12eb7138fb.jpg',
#  '/data/FaceScrub/James_Brolin/face/65d7a4d4edf0413ec3691a440e832d3f89f9b21e.jpg',
#  '/data/FaceScrub/Jim_Carrey/face/5d98ce8108938c93d7edf462cee9ff6e1a4ec11b.jpg',
#  '/data/FaceScrub/Jason_Biggs/face/70f336a6edf81fedc1ed916b6a6fe7609500176f.jpg',
#  '/data/FaceScrub/Tatyana_M._Ali/face/11c4c65194fd93179e58e804183eef761175da40.jpg',
#  '/data/FaceScrub/David_Boreanaz/face/fa73da577cf88a64b004b6fe412168fdfac8f609.jpg',
#  '/data/FaceScrub/Justin_Timberlake/face/43ec9841ef8bc77f81b4669f24920d6823132dd0.jpg',
#  '/data/FaceScrub/Bernard_Hill/face/a8c60eeecf9253d38330d59828f83b1710916e62.jpg',
#  '/data/FaceScrub/Tamara_Braun/face/d409071062a424218c64bc5b99ae13cc33baa047.jpg',
#  '/data/FaceScrub/Sarah_Chalke/face/9c980d40cd42f279bfff5e3d63ccd3ad325574d9.jpg',
#  '/data/FaceScrub/Glenn_Close/face/c7f36fb57a9e1ca0862b95385e145fd13145e9ec.jpg',
#  '/data/FaceScrub/Bradley_Cooper/face/f936cdf1ff44df2e0c7c6c6a03a1006b36b7f003.jpg',
#  '/data/FaceScrub/Ashley_Jones/face/4716b35aa383ce02b131de0b54e97190586ff940.jpg',
#  '/data/FaceScrub/Roseanne_Barr/face/4a52bfee746d3bc5197a908eed7d75340d72072d.jpg',
#  '/data/FaceScrub/Don_Cheadle/face/a3c43b93c94b808d5c10f3462890a1625ceed545.jpg',
#  '/data/FaceScrub/Denzel_Washington/face/d2a9871c59a6b5623493eba43700d656325b255e.jpg',
#  '/data/FaceScrub/Kerr_Smith/face/6ae75449607e2808083337c40c7772585f534429.jpg',
#  '/data/FaceScrub/Valerie_Bertinelli/face/a39e325cf18b18ad1a2cb3f4ff8272508610179e.jpg',
#  '/data/FaceScrub/Patrick_Dempsey/face/c3f375731c84871cc85f8dbeb494b851938f6efd.jpg',
#  '/data/FaceScrub/Jake_Gyllenhaal/face/11b6c4327c826a6f99da7fea02f049672e372d01.jpg',
#  '/data/FaceScrub/Jared_Padalecki/face/784d99aadc60df85d0235f40463872eb3d2d245c.jpg',
#  '/data/FaceScrub/Cheryl_Hines/face/94ba31ca2b0feb6dc34a74d4bac45ce511ed1161.jpg',
#  '/data/FaceScrub/Jasmine_Guy/face/abbb3099ef4515b9fddf293132430f0fe17224a0.jpg',
#  '/data/FaceScrub/Richard_Gere/face/5cf0a90e644fefb2e850089b440e75270161dac4.jpg',
#  '/data/FaceScrub/Matt_Dillon/face/c97ab6026821830af1f727368b7d597d31624af5.jpg',
#  '/data/FaceScrub/Tempestt_Bledsoe/face/21370b0a37b7217e1a9ae1cec54764db5380a518.jpg',
#  '/data/FaceScrub/Dan_Lauria/face/1b2a344703222166b363a9b7bd2499b14e52d529.jpg',
#  '/data/FaceScrub/Adam_Brody/face/8775ad7d2322c59fa2c10ca0605086f0093d283c.jpg',
#  '/data/FaceScrub/Jackie_Chan/face/21c3d9bc253874b8c79fbece5d13333234d7a70d.jpg',
#  '/data/FaceScrub/Justine_Bateman/face/512da9f9c83afad1d4cf8dc248e57df38ce051bd.jpg',
#  '/data/FaceScrub/Jackie_Chan/face/01d5aa37e7462db445f442e67bb143d027c6db02.jpg',
#  '/data/FaceScrub/Lara_Flynn_Boyle/face/54d8ef1b9321ecdd64d1fececd93ce1c437680fa.jpg',
#  '/data/FaceScrub/Audra_McDonald/face/c39ca0a1345773124389cb4a3f1c90be4046989a.jpg',
#  '/data/FaceScrub/David_Cross/face/c26d31675e2a2e25e3588fd932bb707a0aaf592a.jpg',
#  '/data/FaceScrub/Nicole_Eggert/face/17f8b1229bae901199f02f56adbd2bdf09333d00.jpg',
#  '/data/FaceScrub/Mel_Gibson/face/5d9ae369dbbd0e4dafbd508dac20aca8ae9ffb71.jpg',
#  '/data/FaceScrub/Jean_Reno/face/7c282fb61c3b94d2d39dce0cb2788b3cf64cab12.jpg',
#  '/data/FaceScrub/Justin_Timberlake/face/20ad37397a9f26af3275f5b381e1301869877af0.jpg',
#  '/data/FaceScrub/Joan_Collins/face/9bbff15edb37d0d95b1438d669bcfd618795ef6c.jpg',
#  '/data/FaceScrub/Woody_Allen/face/f49aa7b996a65346feaffb847014eb62482c5b89.jpg',
#  '/data/FaceScrub/Selena_Gomez/face/a256eef5ea3af5e69f1588b44e56668262166ac2.jpg',
#  '/data/FaceScrub/Robert_Pattinson/face/4c7ab8d5ab5bac4c10d15f9cbf311e6f0002a09f.jpg',
#  '/data/FaceScrub/Sarah_Hyland/face/2b78905165971f4ee93f263022b9465f56fe91d7.jpg',
#  '/data/FaceScrub/Omid_Djalili/face/075d892fd6692c0fa5313c96b5cf7fafe1507a9a.jpg',
#  '/data/FaceScrub/Jeanne_Cooper/face/28b18e2e96bfc5047332e5cfdd4ebc2149fba7b9.jpg',
#  '/data/FaceScrub/Billy_Zane/face/0446e859b41066355176c506720c2b5c2ec144ff.jpg',
#  '/data/FaceScrub/Ashley_Jones/face/25b381b9d78d90b13692bde70eb97cae286fbe2c.jpg',
#  '/data/FaceScrub/David_Schwimmer/face/f3f0135bcd9dd53424f3ee342b028b3ed354178a.jpg',
#  '/data/FaceScrub/Robert_Patrick/face/0cdc007f69bd4ec0a9c2c7295702d811ba485cfc.jpg',
#  '/data/FaceScrub/Jennette_McCurdy/face/4fb438455d8d101b0ae291a551ea1715ebf41d92.jpg',
#  '/data/FaceScrub/Mark_Wahlberg/face/3daadaf96d4181ed19736f5a876630a20f7f1a55.jpg',
#  '/data/FaceScrub/Heath_Ledger/face/b5efd29df4a3445a721a8de34bdac4a70010cd8f.jpg',
#  '/data/FaceScrub/Ian_McKellen/face/c30dce2e817ae2712a46332994bfe9ec8bb5c709.jpg',
#  '/data/FaceScrub/Christian_Slater/face/a3b4cba768c9bc5c31afc53417b37158b088de24.jpg',
#  '/data/FaceScrub/Dan_Lauria/face/418d863c592bad23d5f629edec2413915cdb8116.jpg',
#  '/data/FaceScrub/Staci_Keanan/face/36c25483c9f1cb90c9d713fa27ede4c379d040a3.jpg',
#  '/data/FaceScrub/Jeanne_Cooper/face/dea9580182d154ad4343c6af5e91e2b23e557287.jpg',
#  '/data/FaceScrub/Richard_E._Grant/face/69c3558b5f84130f32d7534133d8f49a770dca07.jpg',
#  '/data/FaceScrub/Cheryl_Hines/face/4d36b8e36f3f186588f7a3d8155fd58f61b0c5e8.jpg',
#  '/data/FaceScrub/Heath_Ledger/face/b52f57db249a9051ac245c845e5d2e869cde2b91.jpg',
#  '/data/FaceScrub/Amaury_Nolasco/face/5449d25fd717545cf021d18ade59b1dbda218202.jpg',
#  '/data/FaceScrub/James_Brolin/face/ec1a22d94bd56808a17ee11f2efa748f99b3a066.jpg',
#  '/data/FaceScrub/Ashley_Jones/face/a6e2898f4a5fd884e128c44634413a5560b96078.jpg',
#  '/data/FaceScrub/Gene_Hackman/face/a07799b84b3659d9deadad29238d538c717d00c1.jpg',
#  '/data/FaceScrub/Sarah_Hyland/face/7a6f8296f1fba473edb3db5da8876cc0c3bba08a.jpg',
#  '/data/FaceScrub/Lacey_Chabert/face/894905f9cecbfbb9ed28f5f0d6c84359876b6dc7.jpg',
#  '/data/FaceScrub/Patrick_Dempsey/face/6744b25eb31bd738cb9bb0d80c9972aa50ee943a.jpg',
#  '/data/FaceScrub/Ashley_Benson/face/abfbf33a2f60733c975b220835b0dc528752328c.jpg',
#  '/data/FaceScrub/Robert_Patrick/face/2426d5402ee1f9eef032ef178a9b406c4a2555b2.jpg',
#  '/data/FaceScrub/Joe_Manganiello/face/aad44b25e5db09560d2fb036f35a636bef99ce6d.jpg',
#  '/data/FaceScrub/Jon_Voight/face/9014369341a01534ee9de3d4e52183ea7440c3c1.jpg',
#  '/data/FaceScrub/Josie_Bissett/face/7944e2fee9eb9a2e605986d08ecd566907abde91.jpg',
#  '/data/FaceScrub/Rachel_Dratch/face/830755c01f9200bba4269aec8e634ddfb93d8edc.jpg',
#  '/data/FaceScrub/Daniel_Radcliffe/face/5adaa498e9a41ec81cc6b53e1db47fb3079b3558.jpg',
#  '/data/FaceScrub/Joan_Collins/face/64eb66f8aaab04a74e8e869d094e7b0685c3397c.jpg',
#  '/data/FaceScrub/Roseanne_Barr/face/c7305e11750eedc84f0837ffb03666dc499981a6.jpg',
#  '/data/FaceScrub/Rebecca_Herbst/face/20cf878d5af79bf75ea188982591dd3f15f3f041.jpg',
#  '/data/FaceScrub/Josh_Brolin/face/491c5f744c7d3d162604c85f9f7813d585e1f21a.jpg',
#  '/data/FaceScrub/Jonathan_Rhys_Meyers/face/50a996fb50057b9c980b00862d6c92fb685ff0b4.jpg',
#  '/data/FaceScrub/Nicole_Eggert/face/ba62c5185dee45bab4248e2381b43875ed99fbba.jpg',
#  '/data/FaceScrub/Heath_Ledger/face/0989596a26996279bc1dfbe41e1b308e0b69ffb2.jpg',
#  '/data/FaceScrub/Chris_Kattan/face/95f3e9cc4df3246f930efd454cfe36c7cb83b8de.jpg',
#  '/data/FaceScrub/Chris_Klein/face/5cf0512846ea7bde0503f627a43657664c91b2c5.jpg',
#  '/data/FaceScrub/Jared_Padalecki/face/8e759894659f4087bce3e4a773b6b04987566b4b.jpg',
#  '/data/FaceScrub/Tia_Carrere/face/c290fd1258fb2ced1807286f0221b6d8fd663d68.jpg',
#  '/data/FaceScrub/Lara_Flynn_Boyle/face/08881deaa350cdf884d9b23091a5b545e5ea45a2.jpg',
#  '/data/FaceScrub/David_Boreanaz/face/d9915705d07608b678e9a69faee801c75dba59f5.jpg',
#  '/data/FaceScrub/Ken_Watanabe/face/046e7d532b680ac9017d08b8ccee5781f95614a9.jpg',
#  '/data/FaceScrub/Alyson_Hannigan/face/2b0792c61f1b7806ac776949e06e7d33c7ca0164.jpg',
#  '/data/FaceScrub/Jackie_Chan/face/63743d71b77208270e20a5b482f430681efc42e6.jpg',
#  '/data/FaceScrub/Justine_Bateman/face/807d8e9e3e9b9ebb9c3f71978998df3f0545ef26.jpg',
#  '/data/FaceScrub/Jon_Voight/face/3528a11b8da2535f002031e8b80112277a5ba884.jpg',
#  '/data/FaceScrub/Shannen_Doherty/face/0e0f3343e8e03280710dcd4ef1d5f711adcbaa93.jpg',
#  '/data/FaceScrub/Patrick_Dempsey/face/f07f11dfcd8e3443a5bcd6f14f3666473c272179.jpg',
#  '/data/FaceScrub/Wendie_Malick/face/825361e239ee0f98cce3dd34dfd44a57cd1d057f.jpg',
#  '/data/FaceScrub/Brendan_Fraser/face/cd0377629753ea8ce5d93c17f1437592ad8de383.jpg',
#  '/data/FaceScrub/Clive_Owen/face/6c5c73082da512760ad6206c0cf64de21a0633df.jpg',
#  '/data/FaceScrub/Jim_Beaver/face/1fda92e8a9cda72b31df67687602d15cabb7d4d7.jpg',
#  '/data/FaceScrub/Marilu_Henner/face/12ac16e7f9486df31ad38f9e593ea4a266b72b31.jpg',
#  '/data/FaceScrub/Jake_Gyllenhaal/face/83c72858b210dc5fe08eda975c359688600b1e7c.jpg',
#  '/data/FaceScrub/Billy_Zane/face/7077058fded7bf4c9e8c2ed773c44e7432f9d6b8.jpg',
#  '/data/FaceScrub/Joan_Collins/face/2f923f3eb47592d9b1b4624e84fc1f5570d698f5.jpg',
#  '/data/FaceScrub/Sarah_Chalke/face/7a820db66ee1253e723fe98c9fa852e79f5a6ae0.jpg',
#  '/data/FaceScrub/Bernard_Hill/face/d483886861c2ee311c1b8cbcfb6b820ef3042757.jpg',
#  '/data/FaceScrub/Chris_Kattan/face/caa95f000b2c2169e8da45ab4cdc735f2a54d997.jpg',
#  '/data/FaceScrub/Jon_Voight/face/6735bdb934c28a26866f1eac12db92d0f5356572.jpg',
#  '/data/FaceScrub/Adam_McKay/face/7b091c5d312696d3354e22182cbf7c362a425ae3.jpg',
#  '/data/FaceScrub/Danica_McKellar/face/62978627690ea976b72b14253466a995d94ba7a8.jpg',
#  '/data/FaceScrub/Rue_McClanahan/face/da72ce8f4a23fa155cb047a22e628f2a765b8302.jpg',
#  '/data/FaceScrub/Jeremy_Irons/face/6754a97c33d7fb5ad0ed2b2a22c7b3754a36709f.jpg',
#  '/data/FaceScrub/Robert_Redford/face/165f12790a3619f62105597aaa5708cf793806fd.jpg',
#  '/data/FaceScrub/Jason_Biggs/face/f4b24c8e3a12dc990ff5a91fd9e165ab55d24610.jpg',
#  '/data/FaceScrub/Kristen_Johnston/face/20853637954f85cd262991435181aea483d87702.jpg',
#  '/data/FaceScrub/Holly_Marie_Combs/face/6b8fc3749c0f0b3222f74727547d2f51937bdd34.jpg',
#  '/data/FaceScrub/Edi_Gathegi/face/c9b99554740c585222de2b95db60799e69b73faa.jpg',
#  '/data/FaceScrub/Justin_Timberlake/face/5917fe0f5ded957305137225510d0ba35840a74f.jpg',
#  '/data/FaceScrub/Elijah_Wood/face/b84a1c5d5a13c31cd97a1a2b100d2646f48acfe1.jpg',
#  '/data/FaceScrub/Debi_Mazar/face/55c5d39140297028862b7fa691e6426620a22019.jpg',
#  '/data/FaceScrub/Mayim_Bialik/face/922f373537ff1aea5cdf69eb8ba2bd3e43825e77.jpg',
#  '/data/FaceScrub/John_Cusack/face/9dfc95e3f56e64b99f13fb52653f97a6ef39e6b9.jpg',
#  '/data/FaceScrub/Neve_Campbell/face/f1ffaaa590cb9676017208903522fe79ce9473f1.jpg',
#  '/data/FaceScrub/Adrienne_Barbeau/face/737fef23582f43d1287636533ce0c4357f9f23e7.jpg',
#  '/data/FaceScrub/Bill_Cosby/face/7f8c0c9600376b8cfd1ded97e4ef70e099078bab.jpg',
#  '/data/FaceScrub/Sasha_Alexander/face/237146fdae2e13d456ec1ae483c48badb1aaee58.jpg',
#  '/data/FaceScrub/Angie_Harmon/face/ff192c38515c9789b043a5524088dddc79339181.jpg',
#  '/data/FaceScrub/Sarah_Michelle_Gellar/face/6c7f038e3236962649aa2c16c6966f408267e856.jpg',
#  '/data/FaceScrub/Jesse_Eisenberg/face/063b8a4423020e32b3999dd655e2c71199cf2a44.jpg',
#  '/data/FaceScrub/Sarah_Hyland/face/33c52b0a05fe554e506996768e9b0eb0926974e3.jpg',
# ...
#  '/data/FaceScrub/Jesse_Eisenberg/face/0ad28303456f792a04d58abcdfe06b2d0c1af11f.jpg',
#  '/data/FaceScrub/Josie_Bissett/face/0043aa3996f77a65ec8923f31a43f6c5beb237dc.jpg',
#  '/data/FaceScrub/Jon_Voight/face/a02f1eed3a0667f4f1fff875078a7d0117a02798.jpg',
#  '/data/FaceScrub/Benicio_Del_Toro/face/648d01e705d3495f2213d3d6ed513888081a2ec0.jpg',
#  '/data/FaceScrub/Anthony_Hopkins/face/47f5e4a123be1d533641aad3a0281ec699ee2b0e.jpg',
#  '/data/FaceScrub/Sasha_Alexander/face/61e436a58d817c3c46fc7cff9d2ee64a19cd179c.jpg',
#  '/data/FaceScrub/Diego_Luna/face/5c8d44a7bf9224ff1c2e5ac7f50d47ab4dd997b3.jpg',
#  '/data/FaceScrub/Roseanne_Barr/face/40141243e627d76dc8c7ea2577902193d62b82c7.jpg',
#  '/data/FaceScrub/Dan_Lauria/face/3624fa365f3293468ba9a02dfece9a79a7d4b348.jpg',
#  '/data/FaceScrub/Cary_Elwes/face/3fdf7596c6a6eaaa7dbd647e349319d84e1c3ee5.jpg',
#  '/data/FaceScrub/Annie_Ilonzeh/face/00bb34e0585937c8e3f7a837cfc754796a75036b.jpg',
#  '/data/FaceScrub/Danica_McKellar/face/ef17aa4ad192f7d54acc0546bd5bc426fdb04d44.jpg',
#  '/data/FaceScrub/Hank_Azaria/face/1e5438eaf28bb28a6b3ab158d6f62eb1beb93e28.jpg',
#  '/data/FaceScrub/Lourdes_Benedicto/face/72ec8addc30075186c6b4adffd6e2ecec5520f93.jpg',
#  '/data/FaceScrub/Jean_Reno/face/93031bdfb7ef34b4d1a3d4f29828d6d4ccffcf35.jpg',
#  '/data/FaceScrub/Danica_McKellar/face/46ecd199829fded68b34babfebd6da09d2e438a0.jpg',
#  '/data/FaceScrub/Adam_Brody/face/1740f2a7a6ee98302047ef3511529133740d1580.jpg',
#  '/data/FaceScrub/Jeremy_Irons/face/8bf4669ecf55972bc59d3276599eeea0fb495adb.jpg',
#  '/data/FaceScrub/Jonah_Hill/face/d0c35d61cbf98bf48269f1caf2ee039c09014368.jpg',
#  '/data/FaceScrub/Alyson_Hannigan/face/c180e7752c013f27bacf5443e6d3bbfcb1420420.jpg',
#  '/data/FaceScrub/Jennette_McCurdy/face/a6cd60043409114b6930e34018d9e659887a8d72.jpg',
#  '/data/FaceScrub/Lisa_Kudrow/face/c598aaedcdb1a414bb6f8f87fee597268ab578ba.jpg',
#  '/data/FaceScrub/McKayla_Maroney/face/73351973472ddc94c8a6915ba87bfc7f054151d6.jpg',
#  '/data/FaceScrub/Nancy_Lee_Grahn/face/197f8dcfb139d4fc278904d5194a56532a9ca81a.jpg',
#  '/data/FaceScrub/Diego_Luna/face/268d5540aa3c0864ee8c85ecc77a0eaa65a5a5ff.jpg',
#  '/data/FaceScrub/Dustin_Hoffman/face/fd8d587abf8be3a6183b41962c7b762fe8df5ff3.jpg',
#  '/data/FaceScrub/Jasmine_Guy/face/da2f207d555f05905703b8d6f163ff2f2c2da43e.jpg',
#  '/data/FaceScrub/Lacey_Chabert/face/f9e9edbfdb553dec15fa660e8ac26147d80f7069.jpg',
#  '/data/FaceScrub/Joan_Collins/face/8e08f4ff069132613fb3bdc77c22b771b65ee4b9.jpg',
#  '/data/FaceScrub/Jennette_McCurdy/face/23986f5fae86d78cc82ccf9b1e8b9b48b318f08a.jpg',
#  '/data/FaceScrub/Rachel_Dratch/face/c53c407f7d4576eeab133349cef2f0e1c42d5bfc.jpg',
#  '/data/FaceScrub/Jessica_Capshaw/face/cad1cd036b692e11e3c9b86f9cabb15e0b77b5ae.jpg',
#  '/data/FaceScrub/Ashley_Benson/face/315d50482a908eb816e992b6aadd46bc557384fc.jpg',
#  '/data/FaceScrub/Burt_Reynolds/face/3c418c70df95de0130ca2465a6fb7b397a928206.jpg',
#  '/data/FaceScrub/Jerry_Seinfeld/face/96bdf8f1b92ce4a6bd757c247ecdb7058a675849.jpg',
#  '/data/FaceScrub/Bradley_Cooper/face/cea2936d1bd6431e21f231462fd6ac12490c5fe7.jpg',
#  '/data/FaceScrub/Morena_Baccarin/face/f05b8b544b6168801bbe5de597834cffe2a04935.jpg',
#  '/data/FaceScrub/Jessica_Capshaw/face/3de4dbc3d6410e21278bef3407ebddcf4b1a53d4.jpg',
#  '/data/FaceScrub/Robert_Patrick/face/af95198d6f81c06d59216c278770dc8a624086a5.jpg',
#  '/data/FaceScrub/Eliza_Dushku/face/2b1c2f646442eb2efa708bc562dbc64cad3f829d.jpg',
#  '/data/FaceScrub/Margaret_Cho/face/0b9e4e8e5c526707a9cf2278d96390d36ad5ceae.jpg',
#  '/data/FaceScrub/Lisa_Bonet/face/2dd7b0b256232b68c359b41839de50f49ddd6879.jpg',
#  '/data/FaceScrub/Amaury_Nolasco/face/6fd5ade9058d605ed9ea5b7efb11ab381b582ea7.jpg',
#  '/data/FaceScrub/Rue_McClanahan/face/10ae39b7e29e8d2231928cd0a5d086fcad85eea0.jpg',
#  '/data/FaceScrub/Martin_Lawrence/face/4244c7f378ec0c32223d454b4ff6d4f1f7fbe965.jpg',
#  '/data/FaceScrub/Gene_Hackman/face/f4a047708e2cd3be084eee4a2da22d5e14b8224f.jpg',
#  '/data/FaceScrub/Andy_Serkis/face/bbd783c81a649ff773dc4b922ffbe62f3748433d.jpg',
#  '/data/FaceScrub/Christian_Slater/face/8e9dd5cd962458d97737f934fcd88d8018a80568.jpg',
#  '/data/FaceScrub/Jackson_Rathbone/face/5ebb6cd5939d3528fb22026d5f3d744602c1df50.jpg',
#  '/data/FaceScrub/Anne_Hathaway/face/b72c8b5c955f83a78f4fea703d069e78b1044888.jpg',
#  '/data/FaceScrub/Danny_Masterson/face/60c09a0cd8d34cea16981357ebfef9cc2dc9ce7a.jpg',
#  '/data/FaceScrub/Robert_Redford/face/725b9f856e0ef39f8e16cafa451a758f33267185.jpg',
#  '/data/FaceScrub/Jeanne_Cooper/face/5bacfd08fd060f73d60cccffda660c2f88d39bb7.jpg',
#  '/data/FaceScrub/Kit_Harington/face/e2bebf73c50ed1124bc98f0ec4705a5493725edf.jpg',
#  '/data/FaceScrub/Drea_de_Matteo/face/577436168ab93a195dded585f3ae1a33c5136f86.jpg',
#  '/data/FaceScrub/Jasmine_Guy/face/409d41f685c6b3fe198740ebd0b2db016a95a9cc.jpg',
#  '/data/FaceScrub/Sarah_Michelle_Gellar/face/6cef3bfe7b82601a406d1551097ea96e3b0efe86.jpg',
#  '/data/FaceScrub/Ian_McKellen/face/7bc8a17926d8b662a78d74b2ff2369e311d10d20.jpg',
#  '/data/FaceScrub/Justine_Bateman/face/16810eeed327b26164114c6ea3436801f6711b70.jpg',
#  '/data/FaceScrub/Kerr_Smith/face/362c2650e9ca2287d6d8cac1f986fcf3b5167eea.jpg',
#  '/data/FaceScrub/Holly_Marie_Combs/face/c52015ec9315e6f28d1732ecf70ba033b0911a7a.jpg',
#  '/data/FaceScrub/Denise_Crosby/face/40e66a69309c70f276f1fb03a2520856ee08ce03.jpg',
#  '/data/FaceScrub/Ashley_Jones/face/b68416f2283e9bf7450d211aafdd4e236ff23655.jpg',
#  '/data/FaceScrub/Angell_Conwell/face/ed1f44f93cc21e043bf53b3f1443530440096ba3.jpg',
#  '/data/FaceScrub/Ashley_Benson/face/2d4babc4290105b9de9cb9066683e6a51d4b9125.jpg',
#  '/data/FaceScrub/Edi_Gathegi/face/3eb681ae639f2a6b6c68b569338d31f889fa7119.jpg',
#  '/data/FaceScrub/Justin_Timberlake/face/7f01f66f0ee4bc0c48c232e697d4796c9b4ed9db.jpg',
#  '/data/FaceScrub/Jesse_Eisenberg/face/094a8e136941f6d8ea75b3cb17ad0e09a05f38be.jpg',
#  '/data/FaceScrub/Martin_Sheen/face/cbf5e33d652714f38a97785b401736a96db4fc9b.jpg',
#  '/data/FaceScrub/Alfred_Molina/face/5d4ac62535b4926c95ac5d62607671c0e61f9bdd.jpg',
#  '/data/FaceScrub/Rue_McClanahan/face/b3bfce14cd8f9e298ac9e82ea9d1c6c8961783db.jpg',
#  '/data/FaceScrub/John_Cusack/face/2e418c59169858de3e55ada453c5fb8a19133828.jpg',
#  '/data/FaceScrub/Samuel_L._Jackson/face/6b529cd464626d0850df57c64495dd27d85cc085.jpg',
#  '/data/FaceScrub/Matt_LeBlanc/face/79ea5661d4c448cc984c40b8f3e3ef7fbe25523a.jpg',
#  '/data/FaceScrub/Angie_Harmon/face/cbc596466472d926dbdcf53584b4909b0780d0d7.jpg',
#  '/data/FaceScrub/Omid_Djalili/face/95096100d8517ec95dffbd32be4d9169ea0404e8.jpg',
#  '/data/FaceScrub/Elijah_Wood/face/f30f16998468b5aad2ffeb3675151aea853fd707.jpg',
#  '/data/FaceScrub/Jackie_Chan/face/d604ec2e0b20e19393895ed44c5e430fbacf986e.jpg',
#  '/data/FaceScrub/Chazz_Palminteri/face/0b7da1acc2ad6a5861c3a00b84819d6f535ea44b.jpg',
#  '/data/FaceScrub/David_Boreanaz/face/6a290a0294e34f7e20b7f1f999d111c38440be7b.jpg',
#  '/data/FaceScrub/Lisa_LoCicero/face/078f10afefce8d8508b1c35e6884cef1d9831e19.jpg',
#  '/data/FaceScrub/Jim_Beaver/face/6e1aaf7017f9fb29fd3f5d0d2f32a74184abe68a.jpg',
#  '/data/FaceScrub/Jennette_McCurdy/face/9e89731cf28f990e758b6769191bc01991aa1ee3.jpg',
#  '/data/FaceScrub/Clive_Owen/face/702b4553d841a8e8ceef7697a97e337cf2b2ed75.jpg',
#  '/data/FaceScrub/J.K._Simmons/face/cf3495705b5cdf860dcacb9c0202db491cd69fbd.jpg',
#  '/data/FaceScrub/Andrea_Bowen/face/c72d89abc8dc5f0871abb3fe1efa8c1ac3904328.jpg',
#  '/data/FaceScrub/Charlie_Sheen/face/4e58917e12b0fc734040899f057abdb9f887edd4.jpg',
#  '/data/FaceScrub/Tina_Fey/face/195f1afaf01d1ec76fa319351caca3744fa47dc4.jpg',
#  '/data/FaceScrub/Tina_Louise/face/35e05b582b5ad3fe8f260ae72347d8b046d299a4.jpg',
#  '/data/FaceScrub/Jean_Reno/face/af60c3d7976624eaf3655fab9b6bfd31228b230c.jpg',
#  '/data/FaceScrub/Billy_Zane/face/3a1e2f4335ef6b8dfefd8906239acf2c65ade31c.jpg',
#  '/data/FaceScrub/Diego_Luna/face/91c00a0bc13f31ae8ab09d6a63e992bfc9a33e38.jpg',
#  '/data/FaceScrub/Adrienne_Barbeau/face/8165b1c2190602385b1cf40cb086ee1eef95d268.jpg',
#  '/data/FaceScrub/Sally_Field/face/c4de8ee9ff86e9db12ae0d119bf252184645f45a.jpg',
#  '/data/FaceScrub/Rob_Schneider/face/7df73aac224a805fe8935b7ecc21bb8a8a3e5f80.jpg',
#  '/data/FaceScrub/Samuel_L._Jackson/face/e1cfabe073cc93ca2ad9900f2c401e8c7a74dcbd.jpg',
#  '/data/FaceScrub/Marilu_Henner/face/7d19b40485d6877c1f8fc14dfa4c83a840db9c6e.jpg',
#  '/data/FaceScrub/Marcia_Cross/face/7ec32f56f74c88d4e779426afeda2562e9367241.jpg',
#  '/data/FaceScrub/John_Travolta/face/c5f390d95938935278a558af4b3a5a4f27bb26af.jpg',
#  '/data/FaceScrub/Hank_Azaria/face/0309c54e63f756d045441601d077c9df075b056f.jpg',
#  '/data/FaceScrub/Josh_Brolin/face/48fb599dec58bb3de8056a8def6427953a59226d.jpg',
#  '/data/FaceScrub/Cheryl_Hines/face/a0e0f1ca49f0b88104a49569907760607128909b.jpg',
#  '/data/FaceScrub/Jeffrey_Tambor/face/4d6c6578d820a085b222f0819139c04904ea9167.jpg',
#  '/data/FaceScrub/David_Schwimmer/face/aad8a3d1b4d7720aa0b4fea8cb5bd32beb526975.jpg',
#  '/data/FaceScrub/Matt_Dillon/face/41a11884625c256f914d2cb851da257bf7c0d77e.jpg',
#  '/data/FaceScrub/Hector_Elizondo/face/ab534f035d1e39f82ff06c86ab9170a56e391656.jpg',
#  '/data/FaceScrub/Jackie_Chan/face/b1fd654189ae45960ab81e9bde79b5e6b3d45159.jpg',
#  '/data/FaceScrub/Denzel_Washington/face/7668c720b054ba933268a4a9d50bb2486dd23e26.jpg',
#  '/data/FaceScrub/Andrea_Bowen/face/7d035d1a270d1922ac7dad9ebb44e1f7bbcc7119.jpg',
#  '/data/FaceScrub/Debi_Mazar/face/e645f797ee848d57c62e91f913c45e2adbc10d36.jpg',
#  '/data/FaceScrub/Ashley_Benson/face/fcc04995665746886bf1c0b79d7ceb7b7585fa29.jpg',
#  '/data/FaceScrub/Nadia_Bjorlin/face/fe6858f8e20bae52273ba82a1be64bdb82e77c4f.jpg',
#  '/data/FaceScrub/Joe_Manganiello/face/c9d5235c495a61903c8f8ad4cb18f7834795b3bc.jpg',
#  '/data/FaceScrub/Kirstie_Alley/face/a4e94a92416defb13ba5abb7cdfa286b8fbb7a5a.jpg',
#  '/data/FaceScrub/Dustin_Hoffman/face/a413ca23b69d9c05d064073b21f7610f60878742.jpg',
#  '/data/FaceScrub/Lisa_Kudrow/face/9f7e5fc785f8ff9c646d2791f3a721933ebe1509.jpg',
#  '/data/FaceScrub/Laurie_Metcalf/face/7e9dfc0b83b6476ca80dae6b181f2f2ea93799f0.jpg',
#  '/data/FaceScrub/James_Brolin/face/d903ad8b2ed9cb3f0c08de5a0396757e8b2f3b24.jpg',
#  '/data/FaceScrub/Kit_Harington/face/e8aa521773aba562d2b6379b3f962a00eafb6d1a.jpg',
#  '/data/FaceScrub/Bill_Cosby/face/aab41a0f3ad9ab051274c730160a8b80fbb2f5c1.jpg',
#  '/data/FaceScrub/Lacey_Chabert/face/384640b78f2a6375e9dfaba4fee88bca787a7eaa.jpg',
#  '/data/FaceScrub/Channing_Tatum/face/5c52038872effb19086a2f237006a96bed3d82a4.jpg',
#  '/data/FaceScrub/David_Schwimmer/face/f1c84611cd618c21252813121be673ffecc0957f.jpg',
#  '/data/FaceScrub/George_Clooney/face/2162a0bce383d77b44996e368da8e0f6f8a98b59.jpg',
#  '/data/FaceScrub/Victor_Garber/face/962641eb751cb51c3e1e710bc7aef44b903a8197.jpg',
#  '/data/FaceScrub/Edi_Gathegi/face/6dbe194800dd86c7ba4d45c481166f5980902a4c.jpg',
#  '/data/FaceScrub/Jennette_McCurdy/face/4bb9af3ba2404dbc7c4c2e4d6d9544bb1048fef0.jpg',
#  '/data/FaceScrub/Lisa_Bonet/face/ce2058e11c1ff6c32c3555760ebb60aac42914fa.jpg',
#  '/data/FaceScrub/Adrienne_Barbeau/face/5f5b8c55b41af95ea2f339ef302f46a165252480.jpg',
#  '/data/FaceScrub/J.K._Simmons/face/db9eca959a5a3ca5733f27b85187b379eadd1aa6.jpg',
#  '/data/FaceScrub/Edi_Gathegi/face/f638366702abd91ce3ceede79e4367d515907b46.jpg',
#  '/data/FaceScrub/Glenn_Close/face/3f72614cec9d5706fa3c6aa0f1deb11fb722159c.jpg',
#  '/data/FaceScrub/Ben_McKenzie/face/06d95aea2ca9ac681ea4a101cc87113842823e40.jpg',
#  '/data/FaceScrub/Matt_LeBlanc/face/9078f8cdde2b8faa70644b5ba44c1ba969348489.jpg',
#  '/data/FaceScrub/Matthew_Perry/face/785bc34721f56298d86c03f6854a7ad7767a56b7.jpg',
#  '/data/FaceScrub/Roseanne_Barr/face/ef4f31cf330e8a32e67c7e7c622edb6d5d414dfa.jpg',
#  '/data/FaceScrub/George_Clooney/face/a2c2f1fe64f358c02ca3a9f814cbbd61b4b1fa96.jpg',
#  '/data/FaceScrub/Sarah_Chalke/face/b600324c5596e37b5f2b0140805fba1f10437491.jpg',
#  '/data/FaceScrub/Jared_Padalecki/face/30b45a59e8638ab148eff0464cc02654d4b3ce1e.jpg',
#  '/data/FaceScrub/Woody_Allen/face/561aa611dc0e9bfd0c1a6704fe64d96e8af65616.jpg',
#  '/data/FaceScrub/Elizabeth_Berkley/face/ece603c2087c58dd4a08339d2a58e627d661f710.jpg',
#  '/data/FaceScrub/John_Cusack/face/9b9c121b39826dcd50e530f0668a3f7bd40f1f82.jpg',
#  '/data/FaceScrub/Jamie_Foxx/face/91f9b66b07a9b1936e22e0c47998da0c1b7054b5.jpg',
#  '/data/FaceScrub/Angell_Conwell/face/fdb2d69515d8f3310a5b7ed991d84e3d59b1e1be.jpg',
#  '/data/FaceScrub/Jamie_Foxx/face/bf36a4161b939d660d6f998984038f3c829f1425.jpg',
#  '/data/FaceScrub/Adam_Sandler/face/036e47d5077a4be5fbc3d986e80b54f08a07ff75.jpg',
#  '/data/FaceScrub/Ashley_Jones/face/4b66c35b2ee1a6a5e2fc39ea4f5cf6caa7c94d6a.jpg',
#  '/data/FaceScrub/Jasmine_Guy/face/b2e0a284e319065378b2d7c716890d2be4e91596.jpg',
#  '/data/FaceScrub/Elizabeth_Berkley/face/2924b927e31f5495ab8c80692c5166115750540a.jpg',
#  '/data/FaceScrub/Gates_McFadden/face/511ecd8f7e95004e4e498e892b6baeec9a25f0b7.jpg',
#  '/data/FaceScrub/Tamara_Braun/face/0ed5566b1528dbdb2752a9634b4e2ad9fba2328c.jpg',
#  '/data/FaceScrub/Sasha_Alexander/face/ddec69c3b2e3298b42e1310848e53f1f419e0b0f.jpg',
#  '/data/FaceScrub/Natalia_Livingston/face/41f63cc32c5123cc6f3785a7274d54c98bf78629.jpg',
#  '/data/FaceScrub/Margaret_Cho/face/9fd310f295f8b3c9765e70fefeed8fbb2ad29664.jpg',
#  '/data/FaceScrub/Danny_Masterson/face/004e3711857a13ff10a33adf0a47cfa913c54701.jpg',
#  '/data/FaceScrub/Glenn_Close/face/998c4451634d9142dc7ec6f2483a121006ce352d.jpg',
#  '/data/FaceScrub/George_Clooney/face/122d45494b8d490325747b521e9297b051597186.jpg',
#  '/data/FaceScrub/Charlie_Sheen/face/50c98bf9c1e98361b0324a985292d01b0e44b024.jpg',
#  '/data/FaceScrub/Lesley-Anne_Down/face/703515c39e98c1efed9647b97921a17b76a4ce9e.jpg',
#  '/data/FaceScrub/Rupert_Grint/face/4c8fb2c3fcd2e599e848b56a0bdbfbcf31cee6b7.jpg',
#  '/data/FaceScrub/David_Schwimmer/face/b1ddbebf2b3a7c07907992f6c2b9c45e260d6e4b.jpg',
#  '/data/FaceScrub/Lisa_Kudrow/face/451941401630f918be59f3f30a6ae492a8ab3269.jpg',
#  '/data/FaceScrub/Robert_Pattinson/face/9dd6dc79eb4413fea9ef7569408d5b762f969182.jpg',
#  '/data/FaceScrub/Josh_Duhamel/face/50416c5704ea7777907e193616aa040d5d396b69.jpg',
#  '/data/FaceScrub/Shannen_Doherty/face/0c852536d67bec26769773a17e7403ea12e31a42.jpg',
#  '/data/FaceScrub/Josh_Brolin/face/a7084f9a1eff4ba44e854fc68070ae7b1af74da3.jpg',
#  '/data/FaceScrub/Valerie_Bertinelli/face/4ee9990c7d32cad3ceb0595a18a4385062341ce1.jpg',
#  '/data/FaceScrub/Channing_Tatum/face/67793c8afe0803e94fa19b1798678d8d76b837ff.jpg',
#  '/data/FaceScrub/Christel_Khalil/face/e300a690ccdffbb809aecae09747d21e53434d90.jpg',
#  '/data/FaceScrub/Eliza_Dushku/face/5abc7ebd457508774ff76b3190f2e214fca04bd5.jpg',
#  '/data/FaceScrub/Danny_Masterson/face/b38d099b62e69a3066adb6f2dbe5d6715b359213.jpg',
#  '/data/FaceScrub/Mackenzie_Aladjem/face/90e4eb8339668f774fad84f7f96130dff8d8a9dc.jpg',
#  '/data/FaceScrub/Keanu_Reeves/face/69ffa888e3afef87dba19e941fb4345cd4115f18.jpg',
#  '/data/FaceScrub/Jasmine_Guy/face/94c1dcc8d491e0dee93249a56db049da82cd6e49.jpg',
#  '/data/FaceScrub/Robert_Patrick/face/1161bbd66a67caa01b009e25ed239079dd25e3c8.jpg',
#  '/data/FaceScrub/Tina_Fey/face/e50ff8ad3861332687b00a9e77093ae049fa6974.jpg',
#  '/data/FaceScrub/Tia_Carrere/face/183cb07e2a9635fad62e1f760f299d438df1777b.jpg',
#  '/data/FaceScrub/Melina_Kanakaredes/face/5ea60875cb7916690080362056686e96ca3520e6.jpg',
#  '/data/FaceScrub/Burt_Reynolds/face/f4e26d07b349ef6318e8c1d194fd441aaa0571af.jpg',
#  '/data/FaceScrub/Roseanne_Barr/face/159b73ca3a11cc6ff1d4a9e357dd4d1869d49ca6.jpg',
#  '/data/FaceScrub/Drea_de_Matteo/face/672bafc60bd8e20c718eaa4e5268d30647ef0909.jpg',
#  '/data/FaceScrub/Angell_Conwell/face/55ba80e5b9558f370cca8141287220e63da94a1d.jpg',
#  '/data/FaceScrub/Josh_Brolin/face/f4f5ef52bf793ec64155a29a0390c0e17a6cf166.jpg',
#  '/data/FaceScrub/Tina_Fey/face/556687efddb06a548dfaabe38c6cf827f226ab0d.jpg',
#  '/data/FaceScrub/Karl_Urban/face/ac8f23c6f2fb9088172f2c30e6f0c36c0a8aa032.jpg',
#  '/data/FaceScrub/Cheryl_Hines/face/a9f408d95b293bf06cde3ce5445437bf2bc546ad.jpg',
#  '/data/FaceScrub/Justine_Bateman/face/1b8b3616e0f0cd704daad432a9656423bd28b983.jpg',
#  '/data/FaceScrub/Peter_Sarsgaard/face/d6b5bdcf0acbf87d3353500d0db0812472f8f31a.jpg',
#  '/data/FaceScrub/Joe_Manganiello/face/cc27ce7f31cfa116d08df64e33c18992b3778760.jpg',
#  '/data/FaceScrub/Hector_Elizondo/face/2e2a40b2e31f20b5139d550d6a3763a9dbcccb23.jpg',
#  ...]

# %%
pred_u,gt_u = pred_network(utility_output,input_image,200,data_generator_test,n_val=None,flag=0,sess=sess)
pred_s,gt_s = pred_network(secret_output,input_image,2,data_generator_test,n_val=None,flag=1,sess=sess)

# %%
# !ls /data
# Out:
# ATTFaces   ISBI   NICO		    Titanic		 faceScrub.zip
# CelebA	   MIMIC  NetflixPrizeData  Waymo
# FaceScrub  MNIST  SVNH		    cifar-10-batches-py

# %%
print('Raw Test acc u top 5:' ,get_categorical_performance(pred_u,gt_u,ntop = 5))
print('Raw Test acc s:' ,get_categorical_performance(pred_s,gt_s,ntop = 1))
# Out:
# Raw Test acc u top 5: 0.9749560632688928
# Raw Test acc s: 0.9872583479789103

# %% [markdown]
# # Reload and/or train Filter with MSE loss

# %%
if load_pretrained_filter:
    named_path = os.path.join(pretrain_checkpoint_dir, model_name)
    filter_type_path = 'batch_norm' if use_batchnorm_filter else 'instance_norm'
    named_filter_path = os.path.join(named_path, filter_type_path)
    pretrain_checkpoint_dir_f = os.path.join(named_filter_path, 'filter')


    ckpt = tf.train.get_checkpoint_state(pretrain_checkpoint_dir_f)
    if ckpt and ckpt.model_checkpoint_path:
        ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
        filter_saver.restore(sess, os.path.join(pretrain_checkpoint_dir_f, ckpt_name))
# Out:
# INFO:tensorflow:Restoring parameters from basecheckpoint/SubjectVsGender/instance_norm/filter/filter-999

# %%
if pretrain_filter:
    n_epochs=1
    n_batches = len(data_generator)

    filter_loss_array = np.zeros(n_epochs*n_batches)

    it = -1
    for epoch in range(n_epochs):
        print(epoch)
        data_generator.shuffle()
        for idx in tqdm(np.arange(n_batches), leave=False):
            it+=1

            data_batch = data_generator.__getitem__(idx)
            imgs = data_batch[0][0]
            utility_gt = data_batch[1][0]  
            secret_gt = data_batch[1][1]


            _, filter_loss_curr, = sess.run([filter_solver, filter_loss ], 
                                            feed_dict={input_image: imgs, lr_f_ph: 1e-2})
            filter_loss_array[it]=filter_loss_curr


            scalar_sum = sess.run(
                scalar_summaries['filter_mse_loss'], 
                feed_dict={scalar_summaries['filter_mse_loss_ph']:filter_loss_curr}
            )
            writer.add_summary(scalar_sum, it)
            if it%50==0:
                image_sum = sess.run(
                    image_summaries['merged_image_summary'], 
                    feed_dict={input_image: imgs}
                )
            writer.add_summary(image_sum, it)

            if it %1000 ==999:
                named_path = os.path.join(pretrain_checkpoint_dir, model_name)

                filter_type_path = 'batch_norm' if use_batchnorm_filter else 'instance_norm'
                named_filter_path = os.path.join(named_path, filter_type_path)
                pretrain_checkpoint_dir_f = os.path.join(named_filter_path, 'filter')



                if not os.path.exists(pretrain_checkpoint_dir):
                    os.makedirs(pretrain_checkpoint_dir)
                if not os.path.exists(named_path):
                    os.makedirs(named_path)
                if not os.path.exists(named_filter_path):
                    os.makedirs(named_filter_path)
                if not os.path.exists(pretrain_checkpoint_dir_f):
                    os.makedirs(pretrain_checkpoint_dir_f)
                filter_saver.save(sess, os.path.join(pretrain_checkpoint_dir_f,'filter'), global_step=it)

# %% [markdown]
# # Define and/or load combined model

# %%
opt_vars = utility_optimizer.variables()
opt_vars += utility_raw_optimizer.variables()
opt_vars += secret_optimizer.variables()
opt_vars += filter_optimizer.variables()
opt_vars += combined_optimizer.variables()

reset_optimizer_op = tf.variables_initializer(opt_vars)

# %%
from AdversarialIOPenalty import AIOIGAN

budget_array = np.array([0.5,0.4,0.3,0.2,0.1,0.001])

# Initialize ganClass
ganClass = AIOIGAN(data_generator,
        utility_output, utility_loss, utility_acc, utility_denseonly_solver,
        utility_raw_output, utility_raw_loss, utility_raw_acc, utility_raw_solver,
        secret_output, secret_loss, secret_acc, secret_solver,
        filter_outputs, filter_loss, filter_solver,
        combined_loss, utility_combined_loss, secret_combined_loss, combined_solver,
        budget_ph, lambda_ph, lr_u_ph, lr_u_ph, lr_s_ph, lr_f_ph, lr_c_ph,
        input_image, input_image, utility_gt_ph, secret_gt_ph, secret_prior_ph,
        utility_saver, utility_raw_saver, secret_saver, filter_saver,
        sess,lambda_val=5e1,budget_val = budget_array[0],
        n_f=1,n_s=1,n_u=0,
        lr_u=5e-4,lr_s=5e-4,lr_f=1e-4,lr_c=5e-4, lr_u_r =1e-4, 
        dg_val = data_generator_val,
        Sprior = Ps,Uprior = Pu, 
        model_name=model_name,
        checkpoint_dir=train_checkpoint_dir,
        pretrain_checkpoint_dir=pretrain_checkpoint_dir,
        scalar_summary=scalar_summaries, image_summary=image_summaries,
        use_batchnorm_classifiers=use_batchnorm_classifiers,
        use_batchnorm_filter = use_batchnorm_filter
    )

# %%
#Load a model for a budget previously trained (can comment)
ix_k = 3  #(only one uploaded to git, others will be uploaded to dropbox)
# budget_load = budget_array[ix_k]
# print('######## BUDGET '+str(budget_load))
# print('   ')

# #load budget
# ganClass.load(ganClass.checkpoint_dir,ganClass.pretrain_checkpoint_dir,
#                       load_type='train',budget_val=budget_load)
# ganClass.budget_val = budget_load

# %%
# Visualize some test images
n_it = 1
for idx in np.arange(n_it):
    
    # Get data batch
    data_batch = data_generator_test.__getitem__(idx)
    imgs = data_batch[0][0]
    utility_gt_idx = data_batch[1][0]
    secret_gt_idx = data_batch[1][1]

    # Evaluate raw image
    pUX_aux,pSX_aux = sess.run([ganClass.utility_output, ganClass.secret_output],
                                 feed_dict={ganClass.raw_input_image_ph:imgs}) 
    
    # Get filtered images & evaluate
    gen_imgs = sess.run(ganClass.filter_output, feed_dict={ganClass.input_image_ph: imgs})
    pUY_aux, pSY_aux = sess.run([ganClass.utility_output, ganClass.secret_output],
                                 feed_dict={ganClass.raw_input_image_ph:gen_imgs})

    u_gt = np.argmax(utility_gt_idx[:,:],axis = 1)
    s_gt = np.argmax(secret_gt_idx[:,:],axis = 1)
    
    plt.figure(figsize=(20,18))
    ix_p = 1
    for i in np.arange(8):
        u_top5 = np.argsort(pUY_aux[i,:])[-4:]
        u_top5gt = np.argsort(pUX_aux[i,:])[-4:]

        if s_gt[i] == 0:
            title_str = 'P(Male) = '+str(np.round(pSY_aux[i,s_gt[i]],2))
            title_str_o = 'P(Male) = '+str(np.round(pSX_aux[i,s_gt[i]],2))
        else:
            title_str = 'P(Female) = '+str(np.round(pSY_aux[i,s_gt[i]],2))
            title_str_o = 'P(Female) = '+str(np.round(pSX_aux[i,s_gt[i]],2))

        
        plt.subplot(4,4,ix_p)
        ix_p += 1
        plt.title(title_str_o,fontsize = 16)
        plt.imshow(imgs[i,:,:,:].squeeze(),cmap = 'gray')
        plt.xlabel(' ID: '+str(u_gt[i]) + '; top 5: '+str(u_top5gt),fontsize = 16)
        plt.xticks([])
        plt.yticks([])
        plt.subplot(4,4,ix_p)
        ix_p += 1
        plt.title(title_str,fontsize = 16)
        plt.imshow(gen_imgs[i,:,:,:].squeeze(),cmap = 'gray')
        plt.xlabel( 'top 5: '+str(u_top5),fontsize = 16)
        plt.yticks([])
        plt.xticks([])
    plt.show()

# %% [markdown]
# ### Training cell (uncomment)

# %%
budget_array
# Out:
# array([0.5  , 0.4  , 0.3  , 0.2  , 0.1  , 0.001])

# %%
# Skip false to train#

skip = False

if not skip:
    
    for budget in budget_array[:1]:
        print('-'*80)
        print(budget)
        print('-'*80)

        sess.run(reset_optimizer_op)

        #set budget
        ganClass.budget_val = budget

        ganClass.train(60, sample_interval=100, eval_interval=50, save_image=True)
        save_everything(ganClass,dg = data_generator_test, nu=nu,ns=ns,
                        savepath= 'checkpoint/budget_{:.2e}_summary_NM_unet_inorm_aux.pkl'.format(budget))
# Out:
# --------------------------------------------------------------------------------
# 0.5
# --------------------------------------------------------------------------------
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# ...
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1 is not in all_model_checkpoint_paths. Manually adding it.
#  [*] Reading checkpoint...
# INFO:tensorflow:Restoring parameters from basecheckpoint/SubjectVsGender/batch_norm/utility_raw/utility_raw-13999
# Utility Raw restore success
# INFO:tensorflow:Restoring parameters from checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1
# Utility Filtered restore success
# checkpoint/SubjectVsGender_0.50000/batch_norm/secret
# INFO:tensorflow:Restoring parameters from checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1
# Secret restore success
# INFO:tensorflow:Restoring parameters from checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1
# Filter restore success
# top 5 acc filtered :  0.9705623901581723
# top 5 acc original :  0.9736379613356766
# acc gender :  0.9811072056239016

# %%
print('Done')
# Out:
# Done

# %%
budget_array

# %% [markdown]
# # Train Dense layer of utility for each budget

# %%
ganClass.checkpoint_dir, ganClass.pretrain_checkpoint_dir
n_epochs=20

# %%
#Skip false to train#
skip = False

if not skip:
    
    epochs_array = np.ones(budget_array.shape, dtype=int)*20

    n_batches = len(data_generator)
    s_loss_array=np.zeros(n_epochs*n_batches)
    s_acc_array=np.zeros(n_epochs*n_batches)

    u_loss_dic = {}
    u_acc_dic = {}
    u_pred_dic = {}
    u_gt_dic = {}


    save_data = {}
    for k in np.arange(budget_array.shape[0]):
        n_epochs=epochs_array[k]
        budget_load = budget_array[k]

        ganClass.load(ganClass.checkpoint_dir,ganClass.pretrain_checkpoint_dir,
                          load_type='train',budget_val=budget_load)


        sess.run(reset_optimizer_op)
        it = -1
        u_loss_array=np.zeros(n_epochs*n_batches)
        u_acc_array=np.zeros(n_epochs*n_batches)
        for epoch in range(n_epochs):
            data_generator.shuffle()
            for idx in np.arange(n_batches):
                it+=1

                data_batch = data_generator.__getitem__(idx)
                imgs = data_batch[0][0]
                utility_gt = data_batch[1][0]  
                secret_gt = data_batch[1][1]

                 # Get filtered images
                gen_imgs = sess.run(ganClass.filter_output, feed_dict={ganClass.input_image_ph: imgs})

                (_,utility_loss_curr, pred_u)= sess.run(
                    [ utility_denseonly_solver,utility_loss, utility_output,
                    ], 
                    feed_dict={input_image: gen_imgs, utility_gt_ph: utility_gt, secret_gt_ph: secret_gt,
                        lr_u_ph: 1e-2, lr_s_ph: 1e-2})

                pUY_aux, pSY_aux = sess.run([ganClass.utility_output, ganClass.secret_output],
                                             feed_dict={ganClass.raw_input_image_ph:gen_imgs})

                u_loss_array[it]=utility_loss_curr
                u_acc_array[it]=np.mean(np.argmax(pred_u,1)==utility_gt.argmax(1))

        utility_saver.save(sess,'checkpoint/budget_{:.2e}_udensetrain_inorm_v0.pkl'.format(budget_load))

        pred_uf,gt_uf =  pred_ganclass_network(ganClass,nu,data_generator_test,filtro = True, n_val=None,flag=0)
        print('filtered Test acc u top 5:' ,get_categorical_performance(pred_uf,gt_uf,ntop = 5))

        u_pred_dic[k] = pred_uf
        u_gt_dic[k] = gt_uf
        u_loss_dic[k] = u_loss_array[0:it]
        u_acc_dic[k] = u_acc_array[0:it]

        save_data['u_pred_dic'] = u_pred_dic
        save_data['u_gt_dic'] = u_gt_dic
        save_data['u_loss_dic'] = u_loss_dic
        save_data['u_acc_dic'] = u_acc_dic
        savepath = 'checkpoint/budget_{:.2e}_summary_densetrain.pkl'.format(budget_load)
        import pickle
        with open(savepath, 'wb') as f:
            pickle.dump(save_data, f)
            
        break
# Out:
#  [*] Reading checkpoint...
# INFO:tensorflow:Restoring parameters from basecheckpoint/SubjectVsGender/batch_norm/utility_raw/utility_raw-13999
# Utility Raw restore success
# INFO:tensorflow:Restoring parameters from checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1
# Utility Filtered restore success
# checkpoint/SubjectVsGender_0.50000/batch_norm/secret
# INFO:tensorflow:Restoring parameters from checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1
# Secret restore success
# INFO:tensorflow:Restoring parameters from checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1
# Filter restore success
# INFO:tensorflow:checkpoint/budget_5.00e-01_udensetrain_inorm_v0.pkl is not in all_model_checkpoint_paths. Manually adding it.
# filtered Test acc u top 5: 0.9503514938488576

# %% [markdown]
# # Save Performance for analisis

# %%
ix_k=0

# %%
table_dic = {}
table_labels = ['ix','budget','subject','gender','acc_u(x)','acc_u(y)','acc_ud(y)',
               'conf_u(x)','conf_u(y)','conf_ud(y)','acc_s(x)','acc_s(y)','acc_so(y)',
               'conf_s(x)','conf_s(y)','conf_so(y)','dkl_ux_pu','dkl_udy_pu','dkl_ux_udy',
               'dkl_ux_uy','dkl_sx_ps','dkl_sy_ps','dkl_soy_ps']

Pus_test,Pu_test,Ps_test = get_data_marginals(df_test, nu,ns)

# Change the for to iterate over all budget_array if models have been trained !!!!!:::

# for k in np.arange(budget_array.shape[0]):
for k in np.array([ix_k]):
    budget_load = budget_array[k]
    
    print('######## BUDGET '+str(budget_load))
    print('   ')
    
    #load budget
    ganClass.load(ganClass.checkpoint_dir,ganClass.pretrain_checkpoint_dir,
                          load_type='train',budget_val=budget_load)
    ganClass.budget_val = budget_load
    
    pred_u,gt_u = pred_ganclass_network(ganClass,nu,data_generator_test,filtro = False, n_val=None,flag=0)
    pred_uy,gt_uy = pred_ganclass_network(ganClass,nu,data_generator_test,filtro = True, n_val=None,flag=0)
    pred_sy,gt_sy = pred_ganclass_network(ganClass,ns,data_generator_test,filtro = True, n_val=None,flag=1)

    #load dense utility and evaluate
    utility_saver.restore(sess, 'checkpoint/budget_{:.2e}_udensetrain_inorm_v0.pkl'.format(budget_load))
    pred_uyd,gt_uyd = pred_ganclass_network(ganClass,nu,data_generator_test,filtro = True, n_val=None,flag=0)

    #load original secret (trained on original images) and evaluate
    named_path = os.path.join(pretrain_checkpoint_dir, model_name)
    classifier_type_path = 'batch_norm' if use_batchnorm_classifiers else 'instance_norm'
    named_class_path = os.path.join(named_path, classifier_type_path)
    pretrain_checkpoint_dir_s = os.path.join(named_class_path, 'secret')
    ckpt = tf.train.get_checkpoint_state(pretrain_checkpoint_dir_s)
    if ckpt and ckpt.model_checkpoint_path:
        ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
        secret_saver.restore(sess, os.path.join(pretrain_checkpoint_dir_s, ckpt_name))

    pred_s,gt_s = pred_ganclass_network(ganClass,ns,data_generator_test,filtro = False, n_val=None,flag=1)
    pred_syo,gt_syo = pred_ganclass_network(ganClass,ns,data_generator_test,filtro = True, n_val=None,flag=1)
    

    ### SAVE TABLES ###
    table_array = np.zeros([gt_s.shape[0],23])

    #index test,budget, subject, gender
    table_array[:,0] = np.arange(gt_s.shape[0])
    table_array[:,1] = budget_load
    table_array[:,2] = np.argmax(gt_u,axis = 1)
    table_array[:,3] = np.argmax(gt_s,axis = 1)

    #u(x); u(y); u_dense(y)

    #top 5 accuracy
    for i in np.arange(gt_s.shape[0]):
        table_array[i,4] = get_categorical_performance(pred_u[i,:][np.newaxis,:],gt_u[i,:][np.newaxis,:],ntop = 5)
        table_array[i,5] = get_categorical_performance(pred_uy[i,:][np.newaxis,:],gt_u[i,:][np.newaxis,:],ntop = 5)
        table_array[i,6] = get_categorical_performance(pred_uyd[i,:][np.newaxis,:],gt_u[i,:][np.newaxis,:],ntop = 5)

        #confidence in true label
        table_array[i,7] = pred_u[i,np.argmax(gt_u[i,:])]
        table_array[i,8] = pred_uy[i,np.argmax(gt_u[i,:])]
        table_array[i,9] = pred_uyd[i,np.argmax(gt_u[i,:])]

        #s(x); s(y); s_dense(y)

        #confidence in true label
        table_array[i,13] = pred_s[i,np.argmax(gt_s[i,:])]
        table_array[i,14] = pred_sy[i,np.argmax(gt_s[i,:])]
        table_array[i,15] = pred_syo[i,np.argmax(gt_s[i,:])]

    #top 1 accuracy
    table_array[:,10] = (np.argmax(pred_s,axis = 1) ==  np.argmax(gt_s,axis = 1)).astype('int')
    table_array[:,11] = (np.argmax(pred_sy,axis = 1) ==  np.argmax(gt_s,axis = 1)).astype('int')
    table_array[:,12] = (np.argmax(pred_syo,axis = 1) ==  np.argmax(gt_s,axis = 1)).astype('int')

    #DKLs pUX||pUY_ud
    prior_u = Pu_test[np.newaxis,:]
    table_array[:,16] = np.sum(pred_u*(np.log(np.maximum(pred_u,1e-7))-np.log(np.maximum(prior_u,1e-7))),axis = 1)
    table_array[:,17] = np.sum(pred_uyd*(np.log(np.maximum(pred_uyd,1e-7))-np.log(np.maximum(prior_u,1e-7))),axis = 1)
    table_array[:,18] = np.sum(pred_u*(np.log(np.maximum(pred_u,1e-7))-np.log(np.maximum(pred_uyd,1e-7))),axis = 1)
    table_array[:,19] = np.sum(pred_u*(np.log(np.maximum(pred_u,1e-7))-np.log(np.maximum(pred_uy,1e-7))),axis = 1)
    prior_s = Ps_test[np.newaxis,:]
    table_array[:,20] = np.sum(pred_s*(np.log(np.maximum(pred_s,1e-7))-np.log(np.maximum(prior_s,1e-7))),axis = 1)
    table_array[:,21] = np.sum(pred_sy*(np.log(np.maximum(pred_sy,1e-7))-np.log(np.maximum(prior_s,1e-7))),axis = 1)
    table_array[:,22] = np.sum(pred_syo*(np.log(np.maximum(pred_syo,1e-7))-np.log(np.maximum(prior_s,1e-7))),axis = 1)

    table_dic[k] = table_array
    save_data={}
    save_data['table_dic'] = table_dic
    save_data['table_labels'] = table_labels
    save_data['Pus_test'] = Pus_test
    save_data['Pu_test'] = Pu_test
    save_data['Ps_test'] = Ps_test
    savepath = 'checkpoint/summary_results_testset_SVG_NM_unet_icml.pkl'

    import pickle
    with open(savepath, 'wb') as f:
        pickle.dump(save_data, f)
# Out:
# ######## BUDGET 0.5
#
#  [*] Reading checkpoint...
# INFO:tensorflow:Restoring parameters from basecheckpoint/SubjectVsGender/batch_norm/utility_raw/utility_raw-13999
# Utility Raw restore success
# INFO:tensorflow:Restoring parameters from checkpoint/SubjectVsGender_0.50000/batch_norm/utility_filtered/utility_filtered-1
# Utility Filtered restore success
# checkpoint/SubjectVsGender_0.50000/batch_norm/secret
# INFO:tensorflow:Restoring parameters from checkpoint/SubjectVsGender_0.50000/batch_norm/secret/secret-1
# Secret restore success
# INFO:tensorflow:Restoring parameters from checkpoint/SubjectVsGender_0.50000/instance_norm/filter/filter-1
# Filter restore success
# INFO:tensorflow:Restoring parameters from checkpoint/budget_5.00e-01_udensetrain_inorm_v0.pkl
# INFO:tensorflow:Restoring parameters from basecheckpoint/SubjectVsGender/batch_norm/secret/secret-13999

# %% [markdown]
# # Report Performance

# %%
ix = 0
for k in table_dic.keys():
    table_array = table_dic[k]
    if ix == 0:
        table_cons = np.array(table_array)
    else:
        table_cons = np.concatenate([table_cons,table_array],axis = 0)
    ix += 1

df_data = pd.DataFrame(data=table_cons,columns=table_labels)
df_data.columns

accuracy_table = np.zeros([df_data.budget.unique().shape[0]+1,5])
confidence_table = np.zeros([df_data.budget.unique().shape[0]+1,5])
MI_table = np.zeros([df_data.budget.unique().shape[0]+1,3])

# plot KL(p(x|s)||pS)) vs  KL(p(x|u)||p_u_gt)
plt.figure(figsize = (10,5))
plt.title('Raw Data')
hs = -1*np.sum(Ps_test*np.log(np.maximum(Ps_test,1e-7)))
hu = -1*np.sum(Pu_test*np.log(np.maximum(Pu_test,1e-7)))
plt.plot(np.array([0,hs]),np.array([hu,hu]),'r--',label = 'H(U)',linewidth = 4)
plt.plot(np.array([hs,hs]),np.array([0,hu]),'r--',label = 'H(S)',linewidth = 4)

ax = sns.scatterplot(x="dkl_sx_ps", y='dkl_ux_pu', data=df_data[df_data.budget == df_data.budget.unique()[0]] )
m_ux = df_data[df_data.budget == df_data.budget.unique()[0]].dkl_ux_pu.mean()
m_sx = df_data[df_data.budget == df_data.budget.unique()[0]].dkl_sx_ps.mean()
plt.plot(np.array([0,np.log(2)]),np.array([m_ux,m_ux]),'g--',label = 'I(U;X)',linewidth = 4)
plt.plot(np.array([m_sx,m_sx]),np.array([0,np.log(200)]),'g--',label = 'I(S;X)',linewidth = 4)
plt.xlabel(r'$D_{KL}(p(s|x)||p(s))$')
plt.ylabel(r'$D_{KL}(p(u|x)||p_{gt}(u))$')
plt.legend()
plt.show()

##save tables for k = np.inf (raw data)
accuracy_table[0,0] = np.inf
accuracy_table[0,1] = df_data['acc_u(x)'].mean()
accuracy_table[0,2] = df_data['acc_u(x)'].mean()
accuracy_table[0,3] = df_data['acc_s(x)'].mean()
accuracy_table[0,4] = df_data['acc_s(x)'].mean()

confidence_table[0,0] = np.inf
confidence_table[0,1] = df_data['conf_u(x)'].mean()
confidence_table[0,2] = df_data['conf_u(x)'].mean()
confidence_table[0,3] = df_data['conf_s(x)'].mean()
confidence_table[0,4] = df_data['conf_s(x)'].mean()

MI_table[0,0] = np.inf
MI_table[0,1] = 0
MI_table[0,2] = df_data['dkl_sx_ps'].mean()

cont= 1
for budget in df_data.budget.unique():

    # plot KL(p(y|s)||p(s)) vs  KL(p(x|u)||p(y|u))
    plt.figure(figsize = (10,5))
    plt.title('Budget '+str(budget))
    ax = sns.scatterplot(x="dkl_sy_ps", y='dkl_udy_pu', data=df_data[df_data.budget == budget])
    m_ux = df_data[df_data.budget == budget].dkl_ux_pu.mean()
    m_sx = df_data[df_data.budget == budget].dkl_sx_ps.mean()
    m_sy = df_data[df_data.budget == budget].dkl_sy_ps.mean()
    m_uy = df_data[df_data.budget == budget].dkl_udy_pu.mean()
    plt.plot(np.array([0,np.log(2)]),np.array([m_ux,m_ux]),'g--',label = 'I(U;X)',linewidth = 4)
    plt.plot(np.array([m_sx,m_sx]),np.array([0,np.log(200)]),'g--',label = 'I(S;X)',linewidth = 4)
    plt.plot(np.array([m_sy,m_sy]),np.array([0,np.log(200)]),'y--',label = 'I(S;Y)',linewidth = 4)
    plt.plot(np.array([0,m_sy]),np.array([m_uy,m_uy]),'y--',label = 'I(U;Y)',linewidth = 4)
    plt.plot(np.array([0,hs]),np.array([hu,hu]),'r--',label = 'H(U)',linewidth = 4)
    plt.plot(np.array([hs,hs]),np.array([0,hu]),'r--',label = 'H(S)',linewidth = 4)
    plt.xlabel(r'$D_{KL}(p(s|y)||p(s))$')
    plt.ylabel(r'$D_{KL}(p(u|x)||p(u|y))$')
    plt.legend()
    plt.show()
    
    
    df_aux = df_data[df_data.budget == budget]
    
    ##save tables for k = np.inf (raw data)
    accuracy_table[cont,0] = budget
    accuracy_table[cont,1] = df_aux['acc_u(y)'].mean()
    accuracy_table[cont,2] = df_aux['acc_ud(y)'].mean()
    accuracy_table[cont,3] = df_aux['acc_s(y)'].mean()
    accuracy_table[cont,4] = df_aux['acc_so(y)'].mean()

    confidence_table[cont,0] = budget
    confidence_table[cont,1] = df_aux['conf_u(y)'].mean()
    confidence_table[cont,2] = df_aux['conf_ud(y)'].mean()
    confidence_table[cont,3] = df_aux['conf_s(y)'].mean()
    confidence_table[cont,4] = df_aux['conf_so(y)'].mean()

    MI_table[cont,0] = budget
    MI_table[cont,1] = df_aux['dkl_ux_udy'].mean()
    MI_table[cont,2] = df_aux['dkl_sy_ps'].mean()
    cont += 1

# %%
df_acc = pd.DataFrame(data=accuracy_table,columns=['k','accuracy_top5_u','accuracy_top5_u_dense','accuracy_s_adv','accuracy_s'])
df_conf = pd.DataFrame(data=confidence_table,columns=['k','conf_u','conf_u_dense','conf_s_adv','conf_s'])
df_MI = pd.DataFrame(data=MI_table,columns=['k','I(U;X|Y)','I(S;Y)'])
print(df_acc)
print()
print(df_conf)
print()
print(df_MI)
# Out:
#      k  accuracy_top5_u  accuracy_top5_u_dense  accuracy_s_adv  accuracy_s
# 0  inf         0.973199               0.973199        0.985062    0.985062
# 1  0.5         0.971441               0.952988        0.980668    0.981547
#
#      k    conf_u  conf_u_dense  conf_s_adv    conf_s
# 0  inf  0.919380      0.919380    0.983272  0.983272
# 1  0.5  0.899085      0.879917    0.979339  0.978069
#
#      k  I(U;X|Y)    I(S;Y)
# 0  inf  0.000000  0.658979
# 1  0.5  1.585747  0.658799

# %% [markdown]
# # Compute RCS and compare

# %%
from computeBoundClassTensorflow import boundClass

nu = Pu_test.shape[0]
ns = Ps_test.shape[0]
Pus= Pus_test.reshape([nu,ns])
bC = boundClass(Pus_m=Pus, lambda_base=100)
print(bC.ns, bC.IUS, np.log(bC.ns), bC.HU, np.log(bC.nu))
Isx = df_MI['I(S;Y)'][0]

budget_list = np.zeros([df_data.budget.unique().shape[0]+2])
budget_list[0] = Isx
budget_list[1:-1]= df_data.budget.unique()
budget_list[-1:]= 0
ISY_multi_arr, IUY_multi_arr, results_multi_lst, Hu, IUS, ny_list= bC.get_curve(budget_list=budget_list, 
                                                                                n_y_list=[2*nu])
# Out:
# 2 0.6750241440508944 0.6931471805599453 5.23957902214506 5.298317366548036
# ny 400
# budget 0.6453810913441891
# budget 0.5
# budget 0.4
# budget 0.3
# budget 0.2
# budget 0.1
# budget 0.001
# budget 0.0

# %%
plt.figure(figsize= (6,6))
sns.set(style="darkgrid", font_scale=1.5)
plt.plot(df_MI['I(U;X|Y)'],df_MI['I(S;Y)'],'x',markersize = '10',label = 'Subj.vs.Gen')
plt.plot(Hu - IUY_multi_arr.flatten(),ISY_multi_arr.flatten(),'k--',linewidth = 2,label = 'RCS')
plt.plot([0,Hu],[hs,0],'r--',linewidth = 2,label = 'Achievable Bound')

plt.title('Subject vs Gender',fontsize = 20)
plt.yticks([0,0.2,0.4,hs],['0','0.2','0.4','ln(2)'])
plt.xticks([0,1,2,3,4,Hu],['0','1','2','3','4','ln(200)'])
plt.legend()
# sns.grid()
plt.ylabel(r'$I(S;Y)$')
plt.xlabel(r'$I(U;X|Y)$')
# Out:
# Text(0.5, 0, '$I(U;X|Y)$')
